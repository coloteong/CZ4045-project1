# %%
import spacy
import pandas as pd
import nltk
from nltk.tokenize import sent_tokenize
from textblob import TextBlob
import matplotlib as mpl
from _get_adj_phrases import get_adjective_phrases, get_list_of_phrases
from collections import Counter, defaultdict
import math

# %%
nlp = spacy.load("en_core_web_sm")

# %%
reviews = pd.read_json('../data/reviewSelected100.json', encoding='ISO-8859-1', lines=True)

# %% [markdown]
# A sample of what we get from real life data

# %%
# get reviews for a random business
random_business = reviews.sample(random_state=42)
random_business_id = random_business.iloc[0]['business_id']
small_business_dataset = reviews.loc[reviews['business_id'] == random_business_id]
small_business_dataset.head()
# Out:
#                     review_id                 user_id             business_id  \
# 11200  wysFaMq5S88mF6HLxdh3Vw  4nQ7MOkbc5u-DYUOgjiDsg  yEZn1XpLsEC9uBa-X4xAZw
# 11204  z81YK3CXQJb48BU7ZAcf7A  Ht8iGitRu8kynEubcIhsTQ  yEZn1XpLsEC9uBa-X4xAZw
# 11209  tqajcnZA97HlXkIYrdNVlg  -a0XgJCXoJln2Ue_JMnfIQ  yEZn1XpLsEC9uBa-X4xAZw
# 11212  wXz1c5kz0QB2nvZVTnnkIg  F9ivL7-mzKbfnLO1rKUFFQ  yEZn1XpLsEC9uBa-X4xAZw
# 11258  89J69mHgTTF25Ln97ONTrQ  La1ggB37gvq6UWpEWaMtMA  yEZn1XpLsEC9uBa-X4xAZw
#
#        stars  useful  funny  cool  \
# 11200      4       1      0     0
# 11204      4       7      2     8
# 11209      3       0      0     0
# 11212      5       0      0     0
# 11258      4       2      0     2
#
#                                                     text                date
# 11200  Cute little vietnamese sandwich place on St De... 2016-03-17 14:29:44
# 11204  Hey Hey, it's the SAMMIES!\n\nSuper Yummy here... 2011-11-30 03:26:01
# 11209  Sandwich was good but service was terrible. We... 2016-07-14 18:52:34
# 11212  Super fresh, delicious and cheap Banh Mi in th... 2017-07-28 17:48:01
# 11258  Que ce soit pour leurs délicieux bubbles tea/s... 2012-12-04 21:25:13

# %%
small_business_dataset_reviews = list(small_business_dataset['text'])
# lowercase and correct the text
# this probably works but it takes too long to run so just run this when we want to submit it
# small_business_dataset_reviews = [TextBlob(text).correct() for text in small_business_dataset_reviews]
small_business_dataset_reviews = [sent_tokenize(text) for text in small_business_dataset_reviews]
small_business_dataset_reviews = [item for sublist in small_business_dataset_reviews for item in sublist]

# %%
small_business_phrases = [get_adjective_phrases(text.lower()) for text in small_business_dataset_reviews]
small_business_phrases = [array for array in small_business_phrases if len(array) > 0]
small_business_phrases = [text for sublist in small_business_phrases for text in sublist]
small_business_phrases
# Out:
# also
# usually
# up
# duplicate adverb in subtree: usually
# too
# also
# here
# before
# duplicate adverb in subtree: here
# actually
# also
# back
# since
# maybe
# still
# why
# rarely
# also
# also
# also
# also
# actually
# though
# duplicate adverb in subtree: actually
# so
# overall
# already
# also
# also
# here
# duplicate adverb in subtree: also
# definitely
# however
# also
# so
# also
# upstairs
# still
# too
# duplicate adverb in subtree: still
# so
# always
# duplicate adverb in subtree: so
# also
# only
# duplicate adjective in subtree: ok
# possibly
# here
# undoubtedly
# also
# most
# then
# ever
# also
# here
# duplicate adverb in subtree: also
# here
# also
# also
# just
# duplicate adjective in subtree: sweet
# so
# actually
# even
# really
# probably
# sometimes
# duplicate adverb in subtree: probably
# better
# though
# duplicate adverb in subtree: better
# also
# together
# even
# also
# perhaps
# definitely
# also
# probably
# also
# ['really big',
#  'very reasonable',
#  'really good',
#  'very clear',
#  'so good',
#  'so fresh',
#  'so good',
#  'so cheap',
#  'so good',
#  'quite hungry',
#  'very little',
#  'too way sweet',
#  'just good',
#  'how delicious',
#  'so addictive',
#  'really disappointing',
#  'very sad',
#  'tremendously tasty',
#  'so good',
#  'pretty cheap',
#  'quite cheap',
#  'too lazy',
#  'very healthy',
#  'as good',
#  'how friendly',
#  'as good',
#  'so tasty',
#  'pretty small',
#  'really excited',
#  'so terrible',
#  'very reasonable',
#  'quite tasty',
#  'very tender',
#  'too many',
#  'cloyingly sweet',
#  'completely foreign',
#  'just hungry',
#  'less strong',
#  'too salty',
#  'so delicious',
#  'so good',
#  'most familiar',
#  'very unusual',
#  'definitely best',
#  'very enjoyable',
#  'very good',
#  'very good',
#  'more flavorful',
#  'too bad',
#  'just average',
#  'just average',
#  'so affordable',
#  'so good',
#  'so worth',
#  'very good',
#  'very welcoming',
#  'very too clean',
#  'very good',
#  'very smart',
#  'very friendly',
#  'very small',
#  'most legit',
#  'beautifully balanced',
#  'how much',
#  'unbelievably excited',
#  'absolutely solid',
#  'too large',
#  'so bad',
#  'how many',
#  'pretty cheap',
#  'as good',
#  'that great',
#  'much better',
#  'extremely close',
#  'very big',
#  'that good',
#  'so good',
#  'very impressed',
#  'so professional',
#  'totally unexpected',
#  'quite good',
#  'pretty fresh',
#  'pretty friendly',
#  'more rich',
#  'really tasty',
#  'too difficult',
#  'just right',
#  'so much',
#  'how busy',
#  'also nice also nice also nice also nice ',
#  'very solid',
#  'too sweet',
#  'ridiculously sweet',
#  'so glad',
#  'enough authentic',
#  'too dry',
#  'really quick',
#  'ever busy',
#  'incredibly affordable',
#  'too much',
#  'very flavorful',
#  'too sweet',
#  'very thick',
#  'much better',
#  'so good',
#  'so much',
#  'so many',
#  'so great',
#  'very good',
#  'very communicative',
#  'super fresh',
#  'perfectly crispy',
#  'too sweet',
#  'very nice']

# %%
phrase_counts = Counter(small_business_phrases)
freq_phrases = phrase_counts.most_common(10)
freq_phrases
# Out:
# [('so good', 8),
#  ('very good', 5),
#  ('as good', 3),
#  ('too sweet', 3),
#  ('very reasonable', 2),
#  ('pretty cheap', 2),
#  ('just average', 2),
#  ('much better', 2),
#  ('so much', 2),
#  ('really big', 1)]

# %% [markdown]
# ## Doing it for all of the data that we have

# %%
reviews
# Out:
#                     review_id                 user_id             business_id  \
# 0      8aoJJdKEO3ypoZNszpPu7Q  bGgAL09pxLnV_FFgR4ZADg  ZBE-H_aUlicix_9vUGQPIQ
# 1      J5NOCLdhuhor7USRhtYZ8w  pFCb-1j6oI3TDjr26h2cJQ  e-YnECeZNt8ngm0tu4X9mQ
# 2      PXiLWAYRt3xnHaJ8MB4rzw  mEzc6LeTNiQgIVsq3poMbg  j7HO1YeMQGYo3KibMXZ5vg
# 3      VrLarvxZYJm74yAqtpe9PQ  o-zUN2WEZgjQS7jnNsec0g  7e3PZzUpG5FYOTGt3O3ePA
# 4      C1CUpidlVFprUCkApqzCmA  Wlx0iBXJvk4x0EeOt2Bz1Q  vuHzLZ7nAeT-EiecOkS5Og
# ...                       ...                     ...                     ...
# 15295  qknwFVEh_0KSuexigYBI_A  YMGmyPOU65SMs4H60ltYiw  shIPnFoXrL3dFo5HLH1_HA
# 15296  Y-ZRoyAXCukBK1uK1ZcZCA  JLhOWQiWtGbr14K_KmoWxA  zPEYgVqJ2QNKi45FJi2jvg
# 15297  A8HdjBfhj3pgQuSbwNtDEw  6CoiKFDFXIACJZvv_I_8mQ  zPEYgVqJ2QNKi45FJi2jvg
# 15298  2n1QdrYBRAAe6GKaxEV0jA  _fH4s3ls08eSl_PfX38KIA  etzDsNjkCyQBoJcU2a3U-g
# 15299  4B9k5hmmLWV_lhIYvVcPWA  msRUiBE7Sa5A9145ZdFBow  9Xm2GfG8Rnbb1_CmXyrm3g
#
#        stars  useful  funny  cool  \
# 0          5       0      0     0
# 1          4       0      0     0
# 2          5       2      1     3
# 3          3       0      0     0
# 4          1      11      0     3
# ...      ...     ...    ...   ...
# 15295      1       2      0     0
# 15296      5       0      0     0
# 15297      1       0      1     0
# 15298      5       0      0     0
# 15299      5       0      0     0
#
#                                                     text                date
# 0      We had my Mother's Birthday Party here on 10/2... 2016-11-09 20:07:25
# 1      Good Korean grill near Eaton Centre. The marin... 2015-12-05 05:06:43
# 2      Was recommended to try this place by few peopl... 2014-10-11 05:16:15
# 3      Ambience: Would not expect something this nice... 2016-07-25 03:45:26
# 4      Absolutely the WORST pool company that I have ... 2016-04-11 18:49:11
# ...                                                  ...                 ...
# 15295  This was the worst experience ever. So much so... 2014-07-12 21:58:15
# 15296  We come here every time we hit Vegas! A giant ... 2018-11-10 21:38:49
# 15297  As locals we used  to the this place when it w... 2018-10-13 22:11:22
# 15298  The food was delicious. We were seated in 15 m... 2015-02-15 08:43:46
# 15299  Wonderful spot (the patio) and OH SO EXCELLENT... 2018-10-06 19:00:13
#
# [15300 rows x 9 columns]

# %%
reviews_list = reviews[['business_id', 'text']]
reviews_list = reviews_list.groupby(['business_id'])['text'].apply(','.join).reset_index()
reviews_list
# Out:
#                 business_id                                               text
# 0    --I7YYLada0tSLkORTHb5Q  Had to get my wing fix, I like dry rubs on win...
# 1    -7XWJYkutqhIxLen7Grg1g  Definite recommend. \n\nBut I never would have...
# 2    0Rni7ocMC_Lg2UH0lDeKMQ  We love Barros!! Usually go to other locations...
# 3    0kPm1zEpeXFRg8D2phqgCQ  Coffee is exponentially better than Starbucks,...
# 4    1Fpk8ibHhZYnCw8fnGny8w  Really love the food here! I was a HUGE fan of...
# ..                      ...                                                ...
# 148  yHHVKa9joZAKiBDUp2SkKw  This coffee shop has great coffee, but more im...
# 149  z8Em-bhZI3Mmspml7tj6tg  This was the first time and probably the last ...
# 150  zPEYgVqJ2QNKi45FJi2jvg  Stopped by here for lunch yesterday.  What a d...
# 151  zZ7KDK3GAkBUZzsaqB1A4Q  Staff is SO friendly, I was checked in on once...
# 152  z_RTK0MaxaRHRQ99hDL2QA  So so good. I am a big fan of the NY style piz...
#
# [153 rows x 2 columns]

# %%
# reviews_dict: list of dicts, one for each business
reviews_dict = reviews_list.to_dict('records')

# %%
#trial code
reviews_test = reviews_dict[:2]
test = [get_list_of_phrases(review['text']) for review in reviews_test]
test[0]
# Out:
# always
# necessarily
# here
# also
# though
# here
# twice
# duplicate adverb in subtree: here
# later
# duplicate adverb in subtree: here
# always
# basically
# there
# ago
# duplicate adverb in subtree: there
# ,do
# back
# back
# however
# back
# again
# duplicate adverb in subtree: back
# always
# too
# also
# otherwise
# so
# back
# all
# all
# back
# here
# probably
# usually
# well
# duplicate adverb in subtree: usually
# always
# too
# course
# maybe
# yet
# now
# however
# also
# extremely
# duplicate adverb in subtree: also
# also
# definitely
# recently
# also
# also
# off
# duplicate adverb in subtree: also
# however
# probably
# always
# back
# definitely
# back
# duplicate adverb in subtree: definitely
# again
# duplicate adverb in subtree: definitely
# also
# always
# though
# inside
# best
# instead
# hardly
# duplicate adverb in subtree: instead
# first
# here
# too
# really
# nearby
# duplicate adverb in subtree: really
# definitely
# back!,there
# duplicate adverb in subtree: definitely
# back
# really
# back
# however
# oily
# so
# so
# again
# duplicate adverb in subtree: so
# back
# overall
# always
# always
# really
# maybe
# just
# duplicate adverb in subtree: maybe
# better
# really
# better
# duplicate adverb in subtree: really
# always
# too
# duplicate adjective in subtree: spacious
# where
# so
# here
# so
# always
# sometimes
# otherwise
# generally
# duplicate adverb in subtree: otherwise
# generally
# overall
# also
# nonetheless
# overall
# definitely
# always
# usually
# here
# also
# anyhow
# definitely
# so
# always
# here
# here
# duplicate adverb in subtree: here
# always
# often
# actually
# usually
# only
# always
# probably
# though
# definitely
# here
# regardless
# here
# overall
# however
# also
# unagi
# overall
# also
# too
# also
# even
# here
# always
# nevertheless
# so
# then
# duplicate adverb in subtree: so
# definitely
# duplicate adverb in subtree: so
# so
# still
# always
# sadly
# however
# luckily
# apparently
# definitely
# so
# usually
# duplicate adjective in subtree: juicy
# also
# also
# duplicate adjective in subtree: confused
# also
# overall
# well
# overall
# sometimes
# usually
# probably
# regardless
# all
# out
# here
# so
# obviously
# always
# however
# well
# up
# probably
# all
# apparently
# ugly
# duplicate adjective in subtree: watery
# here
# in
# often
# definitely
# duplicate adjective in subtree: dirt
# here
# anyways
# actually
# regardless
# unfriendly
# overall
# now
# much
# so
# so
# even
# then
# why
# so
# now
# duplicate adverb in subtree: so
# unfriendly
# Counter({'very pleased': 3,
#          'always good always good always good ': 1,
#          'necessarily bad necessarily bad ': 1,
#          'just average': 1,
#          'also fantastic also fantastic also fantastic ': 1,
#          'how good': 1,
#          'how delicious': 1,
#          'very good': 9,
#          'very friendly': 4,
#          'really good': 7,
#          'inside great': 1,
#          'very prompt': 1,
#          'even fewer': 1,
#          'real good': 1,
#          'too much': 2,
#          'pretty decent': 1,
#          'pretty good': 9,
#          'most recent': 1,
#          'pretty average': 1,
#          'way friendlier': 1,
#          'exceptionally good': 1,
#          'much better': 2,
#          'extremely greasy': 1,
#          'very empty': 1,
#          'enough large': 1,
#          'barely hot': 1,
#          'extremely attentive': 1,
#          'very busy': 4,
#          'too many': 1,
#          'super busy': 1,
#          'really nice': 1,
#          'so excited': 1,
#          'too low': 1,
#          'very nice': 1,
#          'too busy': 2,
#          'how busy': 1,
#          'just wonderful': 1,
#          'pretty awesome': 1,
#          'ridiculously good': 1,
#          'just sad': 1,
#          'very spacious': 2,
#          'all exceptional all exceptional ': 1,
#          'very reasonable': 1,
#          'very marginal': 1,
#          'pretty empty': 1,
#          'always friendly always friendly ': 1,
#          'very disappointing': 1,
#          'very perticular': 1,
#          'so bizarre': 1,
#          'very expensive': 1,
#          'very loud': 1,
#          'just ok': 2,
#          'definitely worth definitely worth ': 1,
#          'very accommodating': 1,
#          'really small': 1,
#          'less complacent': 1,
#          'pleasantly surprised': 1,
#          'very overpriced': 1,
#          'very average': 1,
#          'mostly attentive': 1,
#          'really sure': 1,
#          'so great': 1,
#          'very comfortable': 1,
#          'really plentiful': 1,
#          'how wonderful': 1,
#          'pretty hard': 1,
#          'very large': 2,
#          'very crunchy': 1,
#          'very attentive': 2,
#          'super friendly': 2,
#          'so loud': 1,
#          'fairly quick': 1,
#          'quite good': 1,
#          'very picky': 1,
#          'how accurate': 1,
#          'fairly speedy': 1,
#          'very happy': 1,
#          'so good': 2,
#          'fairly poor': 1,
#          'really busy': 1,
#          'only friendly': 1,
#          'always huge always huge ': 1,
#          'so big': 1,
#          'so many': 1,
#          'most specific': 1,
#          'more concerned': 1,
#          'as many': 1,
#          'more accurate': 1,
#          'always prompt always prompt ': 1,
#          'very dark': 1,
#          'how dark': 1,
#          'consistently delicious': 1,
#          'so addictive': 1})

# %%
# this cell will take some time to run
phrases_dict = [get_list_of_phrases(review['text']) for review in reviews_dict]
# Out:
# always
# necessarily
# here
# also
# though
# here
# twice
# duplicate adverb in subtree: here
# later
# duplicate adverb in subtree: here
# always
# basically
# there
# ago
# duplicate adverb in subtree: there
# ,do
# back
# back
# however
# back
# again
# duplicate adverb in subtree: back
# always
# too
# also
# otherwise
# so
# back
# all
# all
# back
# here
# probably
# usually
# well
# duplicate adverb in subtree: usually
# always
# too
# course
# maybe
# yet
# now
# however
# also
# extremely
# duplicate adverb in subtree: also
# also
# definitely
# recently
# also
# also
# off
# duplicate adverb in subtree: also
# however
# probably
# always
# back
# definitely
# back
# duplicate adverb in subtree: definitely
# again
# duplicate adverb in subtree: definitely
# also
# always
# though
# inside
# best
# instead
# hardly
# duplicate adverb in subtree: instead
# first
# here
# too
# really
# nearby
# duplicate adverb in subtree: really
# definitely
# back!,there
# duplicate adverb in subtree: definitely
# back
# really
# back
# however
# oily
# so
# so
# again
# duplicate adverb in subtree: so
# back
# overall
# always
# always
# really
# maybe
# just
# duplicate adverb in subtree: maybe
# better
# really
# better
# duplicate adverb in subtree: really
# always
# too
# duplicate adjective in subtree: spacious
# where
# so
# here
# so
# always
# sometimes
# otherwise
# generally
# duplicate adverb in subtree: otherwise
# generally
# overall
# also
# nonetheless
# overall
# definitely
# always
# usually
# here
# also
# anyhow
# definitely
# so
# always
# here
# here
# duplicate adverb in subtree: here
# always
# often
# actually
# usually
# only
# always
# probably
# though
# definitely
# here
# regardless
# here
# overall
# however
# also
# unagi
# overall
# also
# too
# also
# even
# here
# always
# nevertheless
# so
# then
# duplicate adverb in subtree: so
# definitely
# duplicate adverb in subtree: so
# so
# still
# always
# sadly
# however
# luckily
# apparently
# definitely
# so
# usually
# duplicate adjective in subtree: juicy
# also
# also
# duplicate adjective in subtree: confused
# also
# overall
# well
# overall
# sometimes
# usually
# probably
# regardless
# all
# out
# here
# so
# obviously
# always
# however
# well
# up
# probably
# all
# apparently
# ugly
# duplicate adjective in subtree: watery
# here
# in
# often
# definitely
# duplicate adjective in subtree: dirt
# here
# anyways
# actually
# regardless
# unfriendly
# overall
# now
# much
# so
# so
# even
# then
# why
# so
# now
# duplicate adverb in subtree: so
# unfriendly
# however
# magically
# definitely
# definitely
# though
# duplicate adverb in subtree: definitely
# also
# actually
# now
# later
# duplicate adverb in subtree: now
# still
# duplicate adverb in subtree: now
# so
# also
# always
# hopefully
# definitely
# well
# just
# duplicate adverb in subtree: well
# ,the
# always
# also
# well
# definitely
# duplicate adjective in subtree: perfect
# always
# however
# before
# therefore
# literally
# just
# probably
# unfortunately
# now
# just
# duplicate adjective in subtree: decent
# also
# duplicate adjective in subtree: fresh
# really
# typically
# usually
# always
# always
# still
# overall
# now
# now
# ever
# downhill
# duplicate adverb in subtree: ever
# still
# only
# back
# duplicate adjective in subtree: ok
# so
# then
# duplicate adverb in subtree: so
# actually
# always
# all
# though
# always
# also
# definitely
# far
# always
# all
# least
# always
# incorrectly
# so
# probably
# back
# duplicate adverb in subtree: probably
# otherwise
# still
# once
# back
# already
# possibly
# even
# there
# definitely
# in
# before
# all
# here
# ever
# here
# though
# now
# out
# completely
# duplicate adverb in subtree: out
# how
# thru
# duplicate adjective in subtree: good
# inside
# so
# then
# all
# least
# however
# so
# so
# how
# duplicate adverb in subtree: so
# there
# actually
# here
# probably
# always
# always
# also
# nonetheless
# usually
# usually
# inside
# duplicate adverb in subtree: usually
# hopefully
# easily
# so
# always
# definitely
# again
# all
# regardless
# always
# duplicate adverb in subtree: regardless
# how
# officially
# so
# again
# only
# still
# still
# much
# seriously
# back
# overall
# usually
# so
# here
# damn
# just
# unfortunately
# definitely
# duplicate adverb in subtree: unfortunately
# however
# though
# well
# inside
# normally
# duplicate adjective in subtree: super
# duplicate adjective in subtree: different
# definitely
# back
# duplicate adverb in subtree: definitely
# however
# there
# now
# still
# just
# so
# here
# also
# so
# mostly
# also
# too
# so
# yet
# finally
# personally
# also
# overall
# so
# however
# still
# duplicate adverb in subtree: however
# however
# really
# so
# so
# also
# too
# maybe
# faster
# duplicate adverb in subtree: maybe
# anyways
# still
# duplicate adverb in subtree: anyways
# here
# just
# though
# less
# all
# also
# too
# once
# yet
# also
# also
# really
# well
# instead
# additionally
# duplicate adjective in subtree: tasty
# duplicate adjective in subtree: excellent
# apparently
# so
# otherwise
# however
# then
# here
# also
# again
# easily
# first
# duplicate adjective in subtree: tender
# also
# too
# bready
# salsa
# maybe
# completely
# overall
# lately
# first
# then
# lastly
# in
# all
# overall
# though
# so
# all
# duplicate adverb in subtree: so
# back
# overall
# definitely
# back
# duplicate adverb in subtree: definitely
# now
# damn
# probably
# maybe
# here
# definitely
# then
# probably
# duplicate adverb in subtree: then
# maybe
# just
# duplicate adverb in subtree: maybe
# back
# inside
# really
# usually
# yet
# down
# how
# certainly
# duplicate adjective in subtree: approachable
# here
# here
# twice
# duplicate adverb in subtree: here
# then
# definitely
# duplicate adverb in subtree: then
# seriously
# better
# duplicate adverb in subtree: seriously
# honestly
# honestly
# so
# there
# duplicate adverb in subtree: so
# early
# duplicate adverb in subtree: so
# always
# definitely
# definitely
# back
# duplicate adverb in subtree: definitely
# yet
# still
# duplicate adverb in subtree: yet
# in
# so
# here
# duplicate adverb in subtree: so
# overall
# so
# duplicate adjective in subtree: modern
# probably
# actually
# overall
# also
# then
# then
# then
# later
# strictly
# though
# really
# far
# yet
# duplicate adjective in subtree: strong
# duplicate adjective in subtree: sexy
# too
# inside
# also
# so
# neat
# really
# where
# also
# technically
# also
# maybe
# then
# always
# however
# there
# duplicate adverb in subtree: however
# already
# just
# so
# now
# so
# now
# duplicate adverb in subtree: so
# soon
# here
# just
# still
# far
# also
# back
# also
# now
# so
# least
# always
# duplicate adverb in subtree: least
# there
# actually
# otherwise
# overall
# maybe
# still
# already
# duplicate adjective in subtree: clean
# still
# back
# also
# so
# certainly
# back
# duplicate adverb in subtree: certainly
# usually
# soon
# soon
# definitely
# seriously
# still
# later
# still
# also
# just
# always
# defiantly
# back
# duplicate adverb in subtree: defiantly
# back
# dually
# still
# still
# ever
# then
# duplicate adverb in subtree: ever
# back
# duplicate adverb in subtree: ever
# only
# always
# here
# also
# there
# also
# just
# however
# there
# then
# literally
# obviously
# obviously
# simply
# before
# definitely
# back
# duplicate adverb in subtree: definitely
# much
# just
# right".well
# duplicate adverb in subtree: just
# even
# probably
# back
# duplicate adverb in subtree: probably
# again
# duplicate adverb in subtree: probably
# really
# now
# duplicate adverb in subtree: really
# around!!,usually
# also
# ever
# definitely
# moreover
# always
# much
# definitely
# here
# actually
# here
# here
# however
# definitely
# back
# duplicate adverb in subtree: definitely
# truly
# definitely
# personally
# afterwards
# there
# duplicate adverb in subtree: afterwards
# overall
# usually
# also
# maybe
# technically
# so
# actually
# ,the
# definitely
# also
# there
# far
# though
# all
# always
# undoubtably
# all
# just
# usually
# definitely
# back
# duplicate adverb in subtree: definitely
# also
# ,first
# second
# here
# far
# too
# honestly
# so
# so
# definitely
# away
# soon
# honestly
# always
# so
# currently
# so
# there
# duplicate adverb in subtree: so
# ever
# actually
# so
# just
# unfortunately
# also
# also
# just
# simply
# duplicate adverb in subtree: just
# also
# also
# still
# duplicate adverb in subtree: also
# however
# so
# however
# now
# though
# recently
# definitely
# so
# however
# ahead
# overall
# aside
# also
# wacky
# there
# overall
# then
# always
# here
# duplicate adverb in subtree: always
# also
# overall
# personally
# just
# also
# far
# gamely
# well
# exactly
# well
# so
# back
# also
# there
# duplicate adverb in subtree: also
# always
# always
# mostly
# definitely
# also
# wacky
# definitely
# duplicate adverb in subtree: wacky
# back
# soon
# duplicate adverb in subtree: back
# together
# there
# out
# duplicate adverb in subtree: there
# then
# totally
# here
# duplicate adverb in subtree: totally
# so
# still
# duplicate adverb in subtree: so
# also
# here
# however
# so
# so
# normally
# regardless
# also
# too
# definitely
# also
# here
# already
# duplicate adverb in subtree: here
# actually
# always
# wacky
# too
# duplicate adjective in subtree: reasonable
# now
# sadly
# only
# duplicate adverb in subtree: sadly
# either
# too
# wacky
# also
# so
# also
# here
# originally
# only
# duplicate adjective in subtree: crazy
# too
# ok
# also
# so
# definitely
# back
# duplicate adverb in subtree: definitely
# again
# duplicate adverb in subtree: definitely
# basically
# so
# all
# duplicate adverb in subtree: so
# off
# back
# back
# apparently
# here
# probably
# again
# overall
# so
# so
# now
# duplicate adverb in subtree: so
# off
# elsewhere
# then
# later
# always
# too
# duplicate adverb in subtree: always
# otherwise
# so
# also
# also
# so
# before
# back
# also
# too
# also
# overall
# however
# overall
# definitely
# overall
# definitely
# duplicate adverb in subtree: overall
# however
# maybe
# always
# also
# constantly
# then
# best
# oily
# once
# here
# though
# already
# here
# also
# seriously
# so
# again
# always
# always
# also
# ago
# there
# otherwise
# out
# only
# ever
# duplicate adverb in subtree: only
# always
# always
# also
# course
# always
# duplicate adverb in subtree: course
# again
# better
# seriously
# also
# always
# duplicate adverb in subtree: also
# however
# then
# overall
# now
# always
# really
# well
# duplicate adverb in subtree: really
# also
# so
# just
# duplicate adverb in subtree: so
# back
# in
# so
# i.e.
# also
# off
# really
# yet
# duplicate adjective in subtree: great
# disappointed!,last
# regardless
# though
# basically
# then
# however
# then
# since
# highly
# only
# duplicate adverb in subtree: highly
# here
# duplicate adverb in subtree: highly
# seriously
# though
# duplicate adverb in subtree: seriously
# objectively
# duplicate adjective in subtree: disappointed
# ago
# regardless
# also
# always
# however
# just
# easily
# currently
# additionally
# however
# overall
# here
# well
# here
# probably
# definitely
# back
# duplicate adverb in subtree: definitely
# here
# always
# also
# also
# always
# however
# so
# really
# duplicate adjective in subtree: ok
# still
# so
# seriously
# even
# well
# certainly
# back
# duplicate adverb in subtree: certainly
# back
# soon
# duplicate adverb in subtree: back
# also
# just
# usually
# also
# here
# also
# always
# there
# actually
# back
# always
# also
# well
# most
# definitely
# duplicate adverb in subtree: most
# back
# duplicate adverb in subtree: most
# always
# also
# outside
# duplicate adverb in subtree: also
# sadly
# always
# even
# always
# also
# back
# always
# all
# also
# here
# just
# around
# ever
# recently
# maybe
# also
# inside
# duplicate adverb in subtree: also
# again
# hopefully
# always
# however
# duplicate adverb in subtree: always
# out
# however
# hopefully
# always
# rude!,great
# inside
# here
# all
# always
# again
# seriously
# now
# there
# before
# duplicate adverb in subtree: there
# also
# just
# ever
# duplicate adverb in subtree: just
# always
# too
# always
# ,the
# well
# still
# there
# duplicate adjective in subtree: broken
# always
# possibly
# anytime
# however
# however
# back
# too
# still
# so
# only
# either
# duplicate adverb in subtree: only
# there
# better
# all
# really
# rather
# now
# there
# long
# duplicate adverb in subtree: there
# also
# heavenly
# then
# always
# there
# back
# duplicate adverb in subtree: there
# even
# also
# also
# so
# really
# duplicate adverb in subtree: so
# always
# too
# now
# there
# also
# probably
# duplicate adverb in subtree: also
# here
# also
# however
# so
# seriously
# maybe
# sometimes
# here
# again
# duplicate adverb in subtree: here
# however
# always
# too
# duplicate adverb in subtree: always
# always
# also
# also
# now
# duplicate adverb in subtree: also
# only
# again
# too
# here
# here
# first
# so
# just
# already
# sadly
# anymore
# duplicate adverb in subtree: sadly
# overall
# again
# there
# duplicate adjective in subtree: perfect
# often
# always
# too
# also
# always
# otherwise
# seriously
# always
# unfortunately
# overall
# just
# also
# honestly
# always
# though
# also
# all
# promptly
# also
# maybe
# luckily
# still
# duplicate adverb in subtree: luckily
# unfortunately
# also
# over
# luckily
# first
# off
# duplicate adverb in subtree: first
# well
# honestly
# always
# here
# there
# indeed
# how
# also
# here
# also
# often
# specifically
# again
# fruendly
# +
# perhaps
# definitely
# more
# duplicate adverb in subtree: definitely
# also
# literally
# too
# only
# well
# duplicate adverb in subtree: only
# duplicate adjective in subtree: good
# here
# recently
# always
# duplicate adjective in subtree: comfortable
# always
# then
# always
# then
# duplicate adjective in subtree: ok
# along
# there
# duplicate adjective in subtree: disappointing
# surprisingly
# over
# though
# also
# always
# often
# next
# first
# also
# so
# second
# just
# though
# first
# also
# here
# here
# duplicate adjective in subtree: darn
# there
# where
# here
# duplicate adverb in subtree: where
# also
# also
# also
# even
# though
# there
# twice
# duplicate adverb in subtree: there
# seriously
# still
# always
# always
# always
# so
# almost
# always
# always
# constantly
# always
# actually
# always
# however
# all
# duplicate adjective in subtree: great
# also
# definitely
# so
# well
# luckily
# also
# also
# clearly
# back
# so
# especially
# when
# duplicate adverb in subtree: especially
# so
# maybe
# back
# generally
# often
# around
# duplicate adverb in subtree: often
# here
# also
# frequent
# duplicate adjective in subtree: crazy
# both
# still
# secondly
# maybe
# always
# too
# also
# everywhere
# also
# duplicate adjective in subtree: bigger
# how
# too
# early
# always
# really
# also
# definitely
# back
# duplicate adverb in subtree: definitely
# definitely
# however
# here
# there
# duplicate adjective in subtree: delish
# definitely
# well
# maybe
# right
# also
# maybe
# ever
# so
# far
# consistently
# now
# here
# mostly
# always
# normally
# much
# so
# then
# here
# away
# least
# probably
# though
# also
# also
# right
# also
# instead
# so
# maybe
# duplicate adverb in subtree: so
# back
# too
# sometimes
# always
# ,we
# however
# ago
# always
# out
# well
# twice
# duplicate adjective in subtree: excellent
# back
# ago
# before
# duplicate adverb in subtree: ago
# also
# only
# away
# duplicate adverb in subtree: only
# back
# again
# duplicate adverb in subtree: back
# all
# well
# here
# here
# so
# so
# here
# all
# also
# there
# duplicate adverb in subtree: also
# truly
# first
# off
# initially
# so
# together
# probably
# actually
# here
# yet
# here
# before
# duplicate adverb in subtree: here
# duplicate adjective in subtree: bad
# also
# here
# now
# duplicate adverb in subtree: here
# usually
# either
# anyways
# why
# back
# first
# literally
# actually
# so
# course
# so
# duplicate adverb in subtree: course
# now
# too
# then
# overall
# all
# too
# also
# so
# then
# always
# duplicate adjective in subtree: usual
# course
# back
# however
# maybe
# well
# always
# always
# back
# second
# probably
# back
# duplicate adverb in subtree: probably
# probably
# inside
# inside
# definitely
# away
# there
# inside
# probably
# otherwise
# literally
# however
# always
# now
# here
# overall
# once
# seriously
# anywhere
# duplicate adverb in subtree: seriously
# ever
# aside
# duplicate adverb in subtree: ever
# also
# always
# also
# blessedly
# duplicate adverb in subtree: also
# always
# just
# well
# in
# so
# though
# overall
# either
# just
# there
# definitely
# back
# duplicate adverb in subtree: definitely
# here
# usually
# also
# too
# definitely
# back
# duplicate adverb in subtree: definitely
# too
# however
# also
# unfortunately
# always
# so
# too
# well
# where
# there
# haven't
# far
# just
# either
# well
# too
# duplicate adverb in subtree: well
# too
# seriously
# anywhere
# duplicate adverb in subtree: seriously
# ever
# aside
# duplicate adverb in subtree: ever
# also
# always
# also
# blessedly
# duplicate adverb in subtree: also
# always
# just
# all
# just
# anymore
# duplicate adverb in subtree: just
# really
# always
# off
# ever
# far
# also
# ever
# here
# before
# duplicate adverb in subtree: here
# always
# so
# well
# also
# also
# so
# definitely
# back
# duplicate adverb in subtree: definitely
# basically
# almost
# now
# just
# also
# definitely
# back
# literally
# also
# still
# usually
# duplicate adjective in subtree: clear
# duplicate adjective in subtree: similar
# upstairs
# outside
# duplicate adverb in subtree: upstairs
# also
# also
# too
# definetly
# definitely
# there
# ago
# duplicate adverb in subtree: there
# also
# downstairs
# so
# maybe
# duplicate adverb in subtree: so
# there
# early
# duplicate adverb in subtree: there
# too
# also
# also
# definitely
# back
# duplicate adverb in subtree: definitely
# here
# only
# definitely
# literally
# overall
# however
# duplicate adjective in subtree: flat
# kayla
# definitely
# just
# here
# duplicate adjective in subtree: friendly
# twice
# too
# certainly
# far
# too
# so
# so
# now
# hardly
# mostly
# back
# there
# quickly
# still
# definitely
# back
# duplicate adverb in subtree: definitely
# again
# duplicate adverb in subtree: definitely
# also
# luckily
# so
# back
# though
# well
# also
# also
# still
# around
# down
# definitely
# more
# less
# duplicate adverb in subtree: more
# here
# before
# duplicate adverb in subtree: here
# probably
# only
# once
# duplicate adverb in subtree: only
# here
# first
# duplicate adjective in subtree: salami
# probably
# everyday
# duplicate adverb in subtree: probably
# still
# actually
# ever
# here
# around
# forever
# duplicate adverb in subtree: around
# so
# though
# apparently
# definitely
# definitely
# so
# definitely
# definitely
# also
# anytime
# now
# seriously
# probably
# duplicate adverb in subtree: seriously
# truly
# always
# yet
# duplicate adjective in subtree: simple
# definitely
# too
# overall
# then
# usually
# damn
# though
# duplicate adjective in subtree: small
# so
# simply
# duplicate adverb in subtree: so
# also
# certainly
# all
# really
# just
# really
# duplicate adjective in subtree: mixed
# already
# around
# also
# also
# just
# maybe
# really
# overall
# apparently
# though
# here
# somehow
# definitely
# literally
# far
# duplicate adjective in subtree: advertised
# too
# overall
# definitely
# duplicate adverb in subtree: overall
# back
# duplicate adverb in subtree: overall
# around
# now
# finally
# always
# aside
# typically
# otherwise
# also
# well
# rather
# now
# usually
# yet
# first
# all
# duplicate adverb in subtree: first
# also
# however
# totally
# honestly
# just
# certainly
# ironically
# possibly
# still
# so
# actually
# then
# here
# definitely
# definitely
# well
# definitely
# normally
# probably
# though
# all
# also
# furthermore
# however
# also
# well
# definitely
# overall
# really
# seriously
# always
# duplicate adjective in subtree: perfect
# back
# definitely
# back
# duplicate adverb in subtree: definitely
# definitely
# so
# probably
# duplicate adverb in subtree: so
# there
# duplicate adverb in subtree: so
# then
# now
# duplicate adverb in subtree: then
# around
# around
# probably
# there
# ago
# duplicate adverb in subtree: there
# then
# ago
# certainly
# so
# so
# even
# all
# so
# hopefully
# actually
# too
# though
# already
# instead
# then
# basically
# only
# once
# well
# ever
# here
# now
# duplicate adverb in subtree: here
# always
# simply
# doubt
# though
# of
# also
# also
# actually
# even
# hopefully
# there
# before
# duplicate adverb in subtree: there
# always
# overall
# ever
# duplicate adverb in subtree: overall
# there
# still
# duplicate adjective in subtree: excellent
# also
# fast
# oily
# here
# twice
# duplicate adverb in subtree: here
# still
# also
# either
# duplicate adverb in subtree: also
# always
# too
# so
# definitely
# still
# much
# also
# also
# either
# however
# maybe
# overall
# again
# also
# so
# back
# probably
# always
# back
# definitely
# back
# duplicate adverb in subtree: definitely
# here
# maybe
# together
# duplicate adverb in subtree: maybe
# then
# maybe
# now
# duplicate adverb in subtree: maybe
# twice
# duplicate adverb in subtree: maybe
# there
# then
# there
# basically
# definitely
# definitely
# below
# literally
# where
# off
# additionally
# back
# also
# next
# back
# just
# also
# simply
# just
# also
# back
# truly
# equally
# so
# definitely
# unfortunately
# so
# also
# ,the
# back
# always
# well
# duplicate adverb in subtree: always
# back
# always
# always
# anymore
# duplicate adverb in subtree: always
# so
# definitely
# out
# duplicate adverb in subtree: definitely
# always
# still
# first
# actually
# duplicate adjective in subtree: great
# before
# all
# lightly
# however
# so
# lastly
# definitely
# so
# here
# duplicate adverb in subtree: so
# long
# so
# simply
# just
# duplicate adjective in subtree: cold
# back
# also
# however
# lastly
# so
# already
# too
# so
# anytime
# so
# also
# close
# all
# certainly
# also
# defiantly
# truly
# definitely
# definitely
# so
# really
# duplicate adverb in subtree: so
# also
# also
# so
# probably
# duplicate adverb in subtree: so
# anyway
# also
# well
# everyday
# definitely
# definitely
# back
# duplicate adverb in subtree: definitely
# also
# usually
# also
# also
# least
# back
# overall
# here
# duplicate adverb in subtree: overall
# definitely
# back
# duplicate adverb in subtree: definitely
# also
# always
# back
# probably
# also
# always
# again
# always
# again
# then
# always
# here
# duplicate adjective in subtree: excellent
# personally
# also
# also
# back
# again
# duplicate adverb in subtree: back
# of
# maybe
# just
# duplicate adverb in subtree: maybe
# always
# too
# duplicate adverb in subtree: always
# just
# both
# so
# obviously
# duplicate adverb in subtree: so
# still
# well
# quickly
# ever
# then
# back
# actually
# simply
# duplicate adjective in subtree: sure
# definitely
# sometimes
# always
# always
# away
# certainly
# back
# duplicate adverb in subtree: certainly
# soon
# duplicate adverb in subtree: certainly
# ago
# here
# so
# however
# actually
# just
# here
# essentially
# course
# around
# also
# basically
# seriously
# also
# definitely
# literally
# how
# so
# next
# duplicate adverb in subtree: so
# unfortunately
# always
# least
# back
# basically
# currently
# always
# so
# primarily
# far
# also
# usually
# surprisingly
# sometimes
# ironically
# honestly
# around
# duplicate adverb in subtree: honestly
# much
# overall
# here
# so
# here
# however
# back
# back
# there
# on
# unfortunately
# again
# well
# here
# back
# too
# too
# overall
# too
# well
# actually
# however
# still
# duplicate adverb in subtree: however
# definitely
# back
# duplicate adverb in subtree: definitely
# definitely
# back
# both
# so
# either
# also
# regardless
# back
# only
# there
# duplicate adverb in subtree: only
# there
# really
# there
# however
# always
# duplicate adverb in subtree: however
# soon
# long
# else
# likely
# also
# definitely
# really
# back
# duplicate adjective in subtree: delicious
# also
# back
# best
# hopefully
# soon
# duplicate adverb in subtree: hopefully
# all
# here
# duplicate adjective in subtree: decent
# only
# only
# also
# inside
# also
# then
# later
# however
# too
# duplicate adjective in subtree: sweet
# well
# definitely
# anyways
# actually
# really
# also
# together
# here
# anymore
# much
# personally
# longer
# always
# just
# longer
# again
# gently
# also
# so
# unfortunately
# still
# so
# again
# already
# there
# all
# originally
# also
# definitely
# daily
# ago
# obviously
# just
# simply
# still
# when
# so
# either
# always
# obviously
# truly
# really
# indeed
# endings!,recently
# here
# away
# up
# duplicate adverb in subtree: away
# arguably
# well
# inordinately
# truly
# really
# totally
# definitely
# still
# ago
# normally
# now
# also
# personally
# also
# previously
# so
# definitely
# duplicate adverb in subtree: so
# nonetheless
# far
# overall
# too
# damn
# so
# so
# additionally
# before
# later
# still
# definitely
# duplicate adjective in subtree: gracious
# here
# first
# definitely
# second
# so
# seriously
# definitely
# back
# duplicate adverb in subtree: definitely
# waverly
# though
# duplicate adverb in subtree: waverly
# before
# really
# always
# also
# also
# even
# prior
# duplicate adverb in subtree: even
# after
# back
# all
# maybe
# once
# even
# so
# there
# definitely
# all
# almost
# also
# here
# now
# duplicate adverb in subtree: here
# also
# again
# also
# overall
# too
# too
# twice
# now
# duplicate adverb in subtree: twice
# truly
# overall
# though
# duplicate adverb in subtree: overall
# again
# sometimes
# next
# now
# basically
# duplicate adverb in subtree: now
# below
# however
# now
# also
# even
# definitly
# far
# just
# now
# across
# why
# duplicate adjective in subtree: dark
# so
# however
# duplicate adjective in subtree: delicious
# definitely
# back
# duplicate adverb in subtree: definitely
# now
# still
# also
# here
# duplicate adverb in subtree: also
# all
# just
# duplicate adjective in subtree: excellent
# just
# there
# back
# also
# still
# secondly
# always
# completely
# again
# too
# definitely
# again
# duplicate adverb in subtree: definitely
# further
# definitely
# clearly
# literally
# back
# course
# best
# literally
# now
# normally
# also
# duplicate adjective in subtree: def
# just
# now
# previously
# twice
# duplicate adverb in subtree: previously
# also
# recently
# twice
# duplicate adverb in subtree: recently
# so
# really
# gristly
# duplicate adverb in subtree: really
# there
# then
# better
# simply
# actually
# here
# before
# duplicate adverb in subtree: here
# maybe
# off
# so
# though
# also
# definitely
# back
# duplicate adverb in subtree: definitely
# actually
# here
# duplicate adverb in subtree: actually
# twice
# duplicate adverb in subtree: actually
# so
# anyway
# apparently
# perhaps
# here
# always
# always
# always
# all
# actually
# normally
# actually
# previously
# also
# overall
# back
# finally
# then
# finally
# duplicate adverb in subtree: then
# far
# even
# then
# also
# definitely
# also
# so
# absurdly
# duplicate adverb in subtree: so
# so
# so
# only
# duplicate adverb in subtree: so
# overall
# there
# so
# just
# duplicate adverb in subtree: so
# always
# ago
# now
# always
# always
# even
# normally
# also
# however
# so
# also
# definitely
# back
# duplicate adverb in subtree: definitely
# always
# also
# also
# away
# seriously
# often
# here
# however
# also
# really
# again
# so
# too
# back
# here
# also
# only
# overall
# even
# then
# up
# quickly
# now
# here
# also
# again
# basically
# already
# definitely
# however
# then
# however
# still
# also
# literally
# always
# always
# there
# though
# duplicate adverb in subtree: there
# always
# also
# nowhere
# duplicate adjective in subtree: spicy
# certainly
# here
# even
# always
# too
# really
# definitely
# again
# duplicate adverb in subtree: definitely
# always
# back
# here
# once
# duplicate adverb in subtree: here
# always
# now
# best
# now
# also
# back
# also
# again
# much
# outside
# duplicate adverb in subtree: much
# definitely
# well
# surprisingly
# again
# just
# clearly
# up
# duplicate adverb in subtree: clearly
# through
# duplicate adverb in subtree: clearly
# probably
# always
# duplicate adjective in subtree: nicer
# well
# here
# before
# duplicate adverb in subtree: here
# here
# forever
# duplicate adverb in subtree: here
# here
# back
# either
# sometimes
# then
# duplicate adverb in subtree: sometimes
# ever
# also
# sadly
# other
# so
# always
# just
# still
# back
# always
# ever
# always
# first
# duplicate adjective in subtree: hard(old
# hard
# then
# first
# duplicate adverb in subtree: then
# always
# anyhow
# just
# better
# so
# also
# already
# all
# always
# either
# overall
# actually
# sadly
# hardly
# duplicate adverb in subtree: sadly
# both
# back
# however
# then
# duplicate adverb in subtree: however
# ever
# back
# duplicate adverb in subtree: ever
# so
# presently
# definitely
# anyway
# here
# again
# duplicate adverb in subtree: here
# now
# duplicate adjective in subtree: great
# also
# also
# only
# twice
# duplicate adverb in subtree: only
# there
# so
# so
# probably
# back
# duplicate adverb in subtree: probably
# again
# duplicate adverb in subtree: probably
# ok
# so
# though
# there
# too
# now
# still
# definitely
# yet
# still
# duplicate adverb in subtree: yet
# too
# also
# always
# also
# too
# duplicate adverb in subtree: also
# there
# honestly
# then
# also
# definitely
# however
# again
# again
# undoubtedly
# right
# literally
# also
# only
# duplicate adverb in subtree: also
# still
# only
# here
# basically
# out
# duplicate adverb in subtree: basically
# so
# also
# thankfully
# also
# also
# thankfully
# also
# across
# simply
# so
# definitely
# back
# duplicate adverb in subtree: definitely
# duplicate adjective in subtree: small
# then
# sometimes
# there
# also
# definitely
# even
# though
# duplicate adverb in subtree: even
# apparently
# probably
# least
# well
# always
# also
# so
# also
# here
# so
# unfortunately
# back
# really
# also
# then
# definitely
# then
# also
# definitely
# definitely
# truly
# sincerely
# in
# duplicate adverb in subtree: sincerely
# overall
# apparently
# also
# overall
# usually
# out
# however
# so
# currently
# duplicate adverb in subtree: so
# so
# now
# again
# duplicate adverb in subtree: now
# consistently
# wether
# here
# well
# overall
# away
# definitely
# back
# duplicate adverb in subtree: definitely
# off
# duplicate adjective in subtree: kind
# now
# absolutely
# also
# still
# even
# always
# too
# there
# honestly
# out
# duplicate adverb in subtree: honestly
# also
# easily
# far
# duplicate adjective in subtree: friendly
# ever
# definitely
# everytime
# even
# down
# then
# only
# duplicate adverb in subtree: then
# up
# all
# duplicate adverb in subtree: up
# also
# here
# there
# too
# duplicate adverb in subtree: there
# always
# here
# always
# really
# much
# before
# ,ok
# all
# always
# always
# overall
# however
# there
# back
# back
# before
# basically
# ever
# always
# always
# always
# definitely
# here
# duplicate adverb in subtree: definitely
# before
# duplicate adverb in subtree: definitely
# definitely
# back
# duplicate adverb in subtree: definitely
# always
# really
# maybe
# always
# now
# always
# back
# least
# oily
# oily
# then
# however
# really
# only
# most
# still
# matter
# duplicate adverb in subtree: still
# sure
# sometimes
# duplicate adverb in subtree: sure
# so
# now
# hardly
# however
# always
# however
# either
# ever
# always
# often
# here
# duplicate adverb in subtree: often
# always
# much
# back
# again
# duplicate adverb in subtree: back
# here
# here
# where
# down
# here
# there
# easily
# just
# once
# duplicate adverb in subtree: just
# then
# usually
# really
# certainly
# just
# sadly
# often
# always
# down
# just
# well
# actually
# here
# so
# probably
# then
# probably
# duplicate adverb in subtree: then
# then
# long
# here
# again
# duplicate adverb in subtree: here
# surprisingly
# always
# unfortunately
# probably
# duplicate adverb in subtree: unfortunately
# back
# duplicate adverb in subtree: unfortunately
# duplicate adjective in subtree: good
# definitely
# back
# duplicate adverb in subtree: definitely
# then
# of
# even
# far
# well
# duplicate adjective in subtree: good
# maybe
# anyhow
# though
# here
# here
# also
# duplicate adjective in subtree: phenomenal
# so
# supposedly
# so
# really
# luckily
# overall
# back
# all
# back
# maybe
# now
# there
# again
# well
# duplicate adjective in subtree: okay
# however
# all
# duplicate adverb in subtree: however
# so
# back
# really
# here
# also
# always
# back
# off
# duplicate adverb in subtree: back
# maybe
# all
# surely
# duplicate adverb in subtree: all
# back
# duplicate adverb in subtree: all
# back
# here
# then
# again
# duplicate adverb in subtree: then
# here
# duplicate adverb in subtree: then
# so
# finally
# duplicate adverb in subtree: so
# back
# horrible
# then
# out
# course
# then
# so
# out
# so
# why
# just
# duplicate adverb in subtree: why
# then
# duplicate adjective in subtree: combative
# up
# however
# probably
# twice
# again
# ago
# just
# back
# immediately
# only
# where
# where
# so
# duplicate adjective in subtree: knowledgeable
# so
# why
# just
# why
# again
# then
# always
# away
# duplicate adverb in subtree: always
# far
# far
# duplicate adverb in subtree: far
# whatsoever
# so
# only
# also
# also
# all
# then
# meanwhile
# just
# back
# nearby
# definitely
# now
# ever
# now
# here
# unfortunately
# now
# duplicate adverb in subtree: unfortunately
# now
# now
# previously
# fast
# over
# so
# out
# however
# still
# only
# only
# now
# back
# maybe
# just
# duplicate adverb in subtree: maybe
# literally
# highly
# so
# really
# normally
# here
# there
# here
# so
# duplicate adjective in subtree: beyond
# so
# now
# duplicate adverb in subtree: so
# back
# duplicate adverb in subtree: so
# still
# always
# overall
# usually
# definitely
# too
# back
# also
# yet
# so
# then
# only
# highly
# duplicate adjective in subtree: clean
# all
# recently
# so
# also
# also
# simply
# only
# so
# still
# rarely
# usually
# really
# quickly
# so
# maybe
# duplicate adverb in subtree: so
# course
# still
# generally
# overall
# so
# duplicate adjective in subtree: uneven
# also
# here
# duplicate adverb in subtree: also
# overall
# there
# here
# now
# definitely
# always
# duplicate adjective in subtree: new
# so
# in
# duplicate adverb in subtree: so
# quickly
# duplicate adverb in subtree: so
# always
# overall
# maybe
# duplicate adjective in subtree: black
# definitely
# back
# duplicate adverb in subtree: definitely
# even
# too
# typically
# far
# now
# always
# there
# duplicate adverb in subtree: always
# well
# always
# really
# anyways
# literally
# definitely
# back
# all
# honestly
# before
# definitely
# always
# however
# usually
# either
# however
# still
# so
# apparently
# too
# now
# now
# here
# duplicate adverb in subtree: now
# so
# however
# overall
# definitely
# here
# however
# definitely
# all
# too
# too
# inside
# always
# inside
# then
# immediately
# finally
# truly
# surely
# definitely
# back
# duplicate adverb in subtree: definitely
# sometimes
# maybe
# still
# there
# so
# however
# really
# otherwise
# unfortunately
# better
# so
# clearly
# just
# truly
# over
# back
# utterly
# first
# even
# later
# still
# duplicate adverb in subtree: later
# actually
# then
# again
# duplicate adverb in subtree: then
# still
# legitimately
# actually
# honestly
# first
# though
# so
# then
# surely
# so
# however
# also
# too
# however
# always
# definitely
# also
# later
# literally
# later
# now
# literally
# literally
# up
# currently
# so
# even
# duplicate adverb in subtree: so
# probably
# only
# here
# duplicate adverb in subtree: only
# here
# duplicate adjective in subtree: amazing
# back
# then
# again
# duplicate adverb in subtree: then
# ago
# then
# overall
# only
# literally
# also
# here
# how
# basically
# honestly
# sure
# now
# regardless
# also
# here
# back
# apart
# finally
# all
# then
# so
# still
# just
# still
# too
# most
# also
# when
# next
# duplicate adverb in subtree: when
# then
# unnecessarily
# duplicate adverb in subtree: then
# so
# there
# all
# here
# also
# currently
# duplicate adverb in subtree: also
# twice
# ago
# maybe
# overall
# clearly
# all
# even
# there
# definitely
# there
# really
# w/
# mostly
# always
# there
# up
# also
# also
# sometimes
# also
# there
# least
# there
# probably
# there
# really
# basically
# always
# definitely
# so
# above
# otherwise
# everywhere
# duplicate adverb in subtree: otherwise
# so
# really
# really
# also
# actually
# however
# twice
# overall
# back
# so
# always
# definitely
# only
# too
# diffidently
# here
# twice
# duplicate adverb in subtree: here
# really
# definitely
# also
# there
# also
# even
# twice
# yet
# even
# away
# here
# ago
# so
# back
# duplicate adverb in subtree: so
# usually
# then
# back
# all
# out
# now
# duplicate adverb in subtree: out
# early
# so
# out
# outdoors
# out
# out
# so
# always
# duplicate adverb in subtree: so
# currently
# therefore
# always
# here
# here
# sometimes
# always
# here
# then
# otherwise
# maybe
# much
# here
# here
# here
# basically
# far
# also
# really
# too
# ever
# first
# there
# duplicate adverb in subtree: first
# there
# also
# there
# now
# ago
# so
# always
# so
# there
# always
# clearly
# always
# probably
# away
# duplicate adverb in subtree: probably
# also
# overall
# also
# honestly
# also
# too
# too
# hopefully
# here
# just
# however
# either
# so
# maybe
# still
# here
# duplicate adverb in subtree: still
# before
# duplicate adverb in subtree: still
# generally
# probably
# though
# definitely
# then
# then
# duplicate adverb in subtree: then
# also
# however
# overall
# here
# now
# duplicate adverb in subtree: here
# however
# also
# however
# so
# ever
# though
# there
# also
# now
# still
# also
# whatsoever
# usually
# though
# well
# however
# too
# back
# again
# duplicate adverb in subtree: back
# seriously
# duplicate adjective in subtree: delicious
# up
# either
# back
# away
# generally
# generally
# really
# around
# here
# normally
# unfortunately
# here
# here
# honestly
# so
# again
# essentially
# really
# anymore
# duplicate adverb in subtree: really
# duplicate adjective in subtree: dirty
# literally
# really
# hopefully
# duplicate adverb in subtree: really
# also
# then
# immediately
# then
# again
# duplicate adverb in subtree: then
# there
# recently
# duplicate adverb in subtree: there
# again
# duplicate adverb in subtree: there
# all
# actually
# however
# then
# again
# duplicate adjective in subtree: alright
# overall
# maybe
# also
# always
# too
# duplicate adverb in subtree: always
# sometimes
# so
# here
# duplicate adverb in subtree: so
# there
# so
# always
# often
# still
# here
# however
# there
# literally
# now
# back
# aprox
# even
# also
# actually
# also
# overall
# also
# also
# overall
# first
# how
# there
# literally
# indeed
# however
# when
# really
# here
# everytime
# only
# here
# ,the
# absolutely
# busy
# also
# either
# also
# easily
# longer
# all
# though
# somewhat
# luckily
# overall
# here
# then
# honestly
# sometimes
# basically
# whenever
# prepared).,not
# duplicate adverb in subtree: whenever
# why
# usually
# here
# before
# duplicate adverb in subtree: here
# only
# before
# duplicate adverb in subtree: only
# duplicate adjective in subtree: tender
# also
# also
# overall
# overall
# so
# overall
# also
# now
# also
# always
# really
# already
# also
# anymore
# too
# so
# also
# also
# so
# also
# furthermore
# definitely
# usually
# however
# sometimes
# so
# sometimes
# usually
# then
# well
# definitely
# back
# duplicate adverb in subtree: definitely
# ,we
# ever
# also
# so
# always
# all
# there
# always
# too
# now
# always
# overall
# much
# also
# there
# actually
# much
# ago
# there
# really
# ago
# unfortunately
# above
# certainly
# back
# duplicate adverb in subtree: certainly
# here
# always
# back
# so
# maybe
# regardless
# here
# there
# always
# actually
# first
# always
# duplicate adverb in subtree: first
# probably
# just
# literally
# either
# really
# certainly
# simply
# anyway
# always
# duplicate adjective in subtree: busy
# so
# however
# then
# apparently
# too
# duplicate adverb in subtree: apparently
# already
# usually
# home
# here
# then
# too
# duplicate adverb in subtree: then
# better
# also
# overall
# also
# so
# originally
# however
# so
# so
# so
# so
# certainly
# yet
# so
# just
# sometimes
# back
# on
# again
# duplicate adverb in subtree: on
# best
# back
# back
# always
# there
# again
# duplicate adverb in subtree: there
# back
# always
# there
# back
# often
# duplicate adverb in subtree: back
# back
# once
# duplicate adverb in subtree: back
# more
# duplicate adverb in subtree: back
# also
# always
# later
# still
# duplicate adverb in subtree: later
# even
# still
# rather
# better
# anyway
# however
# truly
# duplicate adverb in subtree: however
# maybe
# around
# well
# duplicate adverb in subtree: around
# too
# longer
# also
# usually
# usually
# only
# here
# duplicate adverb in subtree: only
# often
# usually
# only
# now
# yet
# well
# all
# definitely
# first
# so
# either
# also
# across
# duplicate adverb in subtree: also
# though
# also
# also
# certainly
# also
# back
# so
# now
# duplicate adverb in subtree: so
# there
# now
# here
# duplicate adverb in subtree: now
# then
# well
# also
# however
# maybe
# also
# however
# still
# even
# now
# also
# here
# though
# there
# probably
# duplicate adverb in subtree: there
# also
# also
# thankfully
# overall
# back
# duplicate adverb in subtree: overall
# now
# so
# still
# duplicate adverb in subtree: so
# apparently
# though
# often
# austere
# here
# there
# basically
# really
# still
# secondly
# probably
# duplicate adverb in subtree: secondly
# however
# definitely
# also
# however
# overall
# north
# too
# so
# also
# duplicate adjective in subtree: frickin
# so
# actually
# too
# portakal
# down
# where
# happier
# also
# also
# now
# much
# both
# so
# still
# apparently
# sure
# so
# maybe
# so
# unarguably
# ever
# duplicate adverb in subtree: unarguably
# really
# sure
# however
# so
# perhaps
# first
# duplicate adjective in subtree: better
# there
# also
# well
# basically
# just
# here
# actually
# then
# so
# far
# now
# visually
# though
# duplicate adjective in subtree: good
# now
# however
# here
# here
# probably
# all
# twice
# better
# elsewhere
# duplicate adverb in subtree: better
# however
# duplicate adjective in subtree: good
# either
# back
# so
# of
# just
# there
# here
# probably
# also
# either
# duplicate adjective in subtree: bad
# there
# best
# though
# there
# too
# also
# definitely
# duplicate adverb in subtree: also
# also
# far
# akin
# duplicate adverb in subtree: far
# however
# too
# probably
# probably
# there
# now
# also
# recommend!,jukebox
# really
# also
# here
# also
# definitely
# then
# also
# definitely
# also
# basically
# so
# though
# therefore
# on
# duplicate adverb in subtree: therefore
# truly
# just
# then
# still
# amazingly
# too
# even
# maybe
# finally
# up
# always
# really
# also
# also
# perhaps
# still
# so
# just
# finally
# also
# back
# so
# even
# also
# also
# back
# definitely
# back
# duplicate adverb in subtree: definitely
# really
# however
# already
# back
# back
# always
# so
# also
# then
# duplicate adverb in subtree: also
# also
# also
# probably
# also
# before
# well
# unfortunately
# angie
# unfortunately
# still
# duplicate adverb in subtree: unfortunately
# then
# back
# always
# well
# still
# nicole
# definitely
# ,az
# above
# truly
# also
# always
# just
# even
# maybe
# really
# always
# duplicate adjective in subtree: clean
# definitely
# also
# once
# however
# so
# really
# in
# now
# sometimes
# so
# so
# substandard
# best
# duplicate adverb in subtree: substandard
# later
# back
# duplicate adverb in subtree: later
# possibly
# long
# also
# so
# also
# so
# likely
# also
# too
# always
# back
# certainly
# back
# duplicate adverb in subtree: certainly
# still
# far
# also
# definitely
# duplicate adjective in subtree: fluffy
# again
# unfortunately
# yet
# too
# either
# hardly
# always
# there
# in
# so
# still
# all
# always
# too
# usually
# usually
# here
# back
# then
# here
# also
# duplicate adjective in subtree: sweet
# duplicate adjective in subtree: sweet
# though
# here
# ever
# overall
# longer
# there
# duplicate adverb in subtree: longer
# so
# still
# duplicate adverb in subtree: so
# still
# absolutely
# also
# literally
# also
# also
# necessarily
# definitely
# so
# always
# maybe
# inside
# always
# here
# back
# again
# duplicate adverb in subtree: back
# clearly
# oddly
# always
# there
# duplicate adverb in subtree: always
# also
# really
# seriously
# just
# duplicate adverb in subtree: seriously
# secondly
# maybe
# duplicate adverb in subtree: secondly
# really
# course
# absolutely
# duplicate adverb in subtree: course
# back
# really
# usually
# also
# too
# also
# here
# also
# unfortunately
# however
# still
# duplicate adverb in subtree: however
# even
# back
# definitely
# also
# so
# really
# duplicate adverb in subtree: so
# too
# absolutely
# usually
# first
# secondly
# all
# duplicate adjective in subtree: bad
# so
# too
# always
# now
# maybe
# still
# so
# unfortunately
# still
# duplicate adverb in subtree: unfortunately
# out
# best
# always
# duplicate adverb in subtree: best
# then
# still
# so
# however
# then
# duplicate adverb in subtree: however
# much
# basically
# first
# so
# then
# all
# around
# just
# back
# also
# occasionally
# nearby
# too
# nt
# necessarily
# duplicate adverb in subtree: nt
# usually
# all
# already
# -the
# usually
# duplicate adverb in subtree: -the
# usually
# also
# so
# so
# just
# duplicate adverb in subtree: so
# however
# here
# so
# just
# so
# already
# least
# too
# maybe
# so
# really
# duplicate adverb in subtree: so
# so
# there
# however
# just
# here
# duplicate adverb in subtree: just
# usually
# overall
# though
# off
# so
# overall
# though
# overall
# there
# now
# duplicate adverb in subtree: there
# actually
# even
# however
# just
# ,the
# clearly
# however
# back
# certainly
# there
# absolutely
# there
# late
# duplicate adverb in subtree: there
# maybe
# lastly
# far
# duplicate adverb in subtree: lastly
# also
# duplicate adjective in subtree: average
# unfortunately
# already
# also
# so
# definitely
# right
# where
# else
# duplicate adverb in subtree: where
# also
# on
# duplicate adverb in subtree: also
# also
# still
# duplicate adverb in subtree: also
# duplicate adjective in subtree: busy
# better
# also
# still
# now
# probably
# either
# well
# here
# ago
# duplicate adverb in subtree: here
# duplicate adjective in subtree: okay
# also
# philly
# even
# rather
# also
# definitely
# though
# now
# back
# now
# seriously
# probably
# there
# duplicate adverb in subtree: probably
# better
# however
# first
# second
# here
# economically
# however
# back
# obviously
# overall
# maybe
# really
# only
# apparently
# either
# definitely
# however
# so
# maybe
# also
# ever
# definitely
# back
# duplicate adverb in subtree: definitely
# though
# so
# however
# here
# on
# far
# back
# also
# again
# always
# too
# duplicate adjective in subtree: fresh
# then
# so
# definitely
# back
# duplicate adverb in subtree: definitely
# duplicate adjective in subtree: rare
# throughout
# short
# here
# all
# either
# always
# also
# once
# even
# well
# also
# too
# definitely
# back
# definitely
# back
# duplicate adverb in subtree: definitely
# so
# definitely
# duplicate adverb in subtree: so
# there
# duplicate adverb in subtree: so
# definitely
# back
# easily
# far
# also
# unfortunately
# all
# duplicate adverb in subtree: unfortunately
# usually
# always
# literally
# also
# overall
# always
# typically
# definitely
# back
# duplicate adverb in subtree: definitely
# back
# then
# definitely
# back
# duplicate adverb in subtree: definitely
# off
# however
# overall
# definitely
# in
# duplicate adverb in subtree: definitely
# too
# here
# back
# all
# ever
# back
# definitely
# here
# now
# duplicate adverb in subtree: here
# there
# also
# across
# here
# only
# so
# probably
# obviously
# definitely
# back
# duplicate adverb in subtree: definitely
# maybe
# definitely
# all
# too
# already
# here
# now
# duplicate adverb in subtree: here
# probably
# still
# just
# probably
# definitely
# so
# last
# duplicate adverb in subtree: so
# least
# duplicate adverb in subtree: so
# clearly
# much
# definitely
# still
# duplicate adverb in subtree: definitely
# really
# definitely
# however
# also
# here
# duplicate adjective in subtree: true
# here
# also
# rather
# also
# also
# still
# so
# there
# just
# really
# just
# actually
# so
# here
# too
# really
# just
# too
# just
# actually
# back
# consistently
# so
# really
# here
# really
# there
# far
# actually
# back
# simply
# anytime
# ago
# now
# though
# back
# also
# then
# literally
# better
# still
# even
# however
# all
# also
# probably
# anyways
# duplicate adverb in subtree: probably
# so
# there
# so
# also
# barely
# finally
# definitely
# definitely
# usually
# still
# decently
# duplicate adverb in subtree: still
# only
# fine
# also
# ever
# overall
# always
# back
# already
# however
# all
# just
# down
# right
# luckily
# here
# perhaps
# though
# definitely
# however
# however
# however
# also
# so
# overall
# maybe
# so
# also
# only
# personally
# firstly
# secondly
# too
# upside
# so
# definitely
# duplicate adverb in subtree: so
# also
# duplicate adjective in subtree: skeptical
# definitely
# actually
# really
# just
# duplicate adverb in subtree: really
# either
# therefore
# definitely
# definitely
# again
# duplicate adverb in subtree: definitely
# maybe
# also
# so
# always
# duplicate adverb in subtree: so
# overall
# much
# still
# so
# mainly
# only
# aside
# already
# duplicate adjective in subtree: spacious
# also
# however
# certainly
# absolutely
# course
# also
# so
# also
# so
# also
# duplicate adjective in subtree: marbled
# usually
# instead
# duplicate adverb in subtree: usually
# here
# before
# also
# finally
# overall
# down
# now
# back
# again
# duplicate adverb in subtree: back
# always
# already
# even
# already
# on
# definitely
# maybe
# especially
# when
# duplicate adverb in subtree: especially
# really
# duplicate adjective in subtree: sorry
# oddly
# always
# duplicate adverb in subtree: oddly
# how
# however
# recently
# duplicate adverb in subtree: however
# unfortunately
# ever
# sometimes
# here
# truly
# also
# also
# duplicate adverb in subtree: also
# so
# essentially
# least
# here
# always
# unfortunately
# here
# duplicate adverb in subtree: unfortunately
# just
# also
# actually
# also
# duplicate adjective in subtree: helpfull
# just
# so
# also
# always
# duplicate adverb in subtree: also
# also
# whoa
# duplicate adverb in subtree: also
# probably
# anyway
# always
# here
# so
# duplicate adjective in subtree: gracious
# so
# here
# finally
# here
# duplicate adverb in subtree: finally
# now
# especially
# longer
# duplicate adjective in subtree: super
# anyways
# yet
# always
# maybe
# then
# duplicate adverb in subtree: maybe
# there
# probably
# also
# so
# all
# so
# sadly
# there
# again
# duplicate adverb in subtree: there
# first
# here
# duplicate adverb in subtree: first
# unfortunately
# there
# duplicate adverb in subtree: unfortunately
# actually
# also
# also
# perhaps
# far
# duplicate adverb in subtree: perhaps
# probably
# moreover
# anyway
# totally
# definitely
# inside
# well
# so
# duplicate adjective in subtree: huge
# tasty
# definitely
# where
# so
# back
# duplicate adverb in subtree: so
# maybe
# overall
# again
# always
# still
# certainly
# both
# later
# too
# here
# basically
# definitely
# here
# seriously
# so
# once
# ago
# so
# back
# there
# early
# duplicate adverb in subtree: there
# unfortunately
# really
# so
# probably
# maybe
# too
# always
# however
# off
# importantly
# definitely
# still
# really
# often
# actually
# off
# actually
# also
# so
# too
# definitely
# then
# well
# always
# so
# actually
# so
# definitely
# back
# duplicate adverb in subtree: definitely
# definitely
# enough
# overall
# also
# by
# unfailingly
# else
# first
# off
# duplicate adverb in subtree: first
# recently
# so
# here
# here
# also
# only
# still
# always
# next
# always
# there
# duplicate adverb in subtree: always
# occasionally
# again
# ago
# duplicate adverb in subtree: again
# again
# almost
# so
# back
# near
# here
# early
# around
# first
# still
# shady
# there
# probably
# here
# why
# duplicate adverb in subtree: here
# away
# ago
# always
# probably
# immediately
# also
# so
# then
# actually
# ferociously
# usually
# still
# also
# suddenly
# then
# there
# duplicate adverb in subtree: then
# ago
# so
# now
# short
# en
# luckily
# now
# just
# up
# duplicate adverb in subtree: just
# so
# duplicate adjective in subtree: shady
# anyway
# later
# still
# duplicate adverb in subtree: later
# ahead
# there
# still
# everywhere
# along
# also
# still
# duplicate adverb in subtree: also
# just
# simply
# duplicate adverb in subtree: just
# actually
# ago
# probably
# longer
# ever
# ever
# definitely
# here
# always
# also
# right
# also
# fast
# always
# there
# duplicate adverb in subtree: always
# already
# still
# there
# up
# also
# now
# back
# so
# here
# so
# now
# duplicate adverb in subtree: so
# later
# still
# duplicate adverb in subtree: later
# back
# sometimes
# even
# off
# far
# duplicate adverb in subtree: off
# least
# nonetheless
# truly
# however
# well
# then
# almost
# actually
# either
# ago
# however
# though
# all
# even
# always
# so
# now
# overall
# well
# really
# back
# so
# course
# still
# duplicate adverb in subtree: course
# always
# then
# then
# why
# so
# where
# also
# overall
# necessarily
# above
# here
# actually
# however
# clearly
# still
# always
# all
# now
# where
# already
# too
# actually
# back
# online
# also
# just
# seriously
# probably
# well
# so
# probably
# back
# duplicate adverb in subtree: probably
# here
# so
# though
# away
# too
# definitely
# forever
# long
# duplicate adverb in subtree: forever
# far
# soon
# away
# here
# far
# now
# so
# now
# then
# too
# unfortunately
# also
# here
# also
# even
# however
# still
# simply
# also
# back
# also
# always
# always
# always
# also
# always
# always
# definitely
# back
# duplicate adverb in subtree: definitely
# actually
# out
# late
# duplicate adverb in subtree: out
# so
# only
# there
# duplicate adverb in subtree: only
# here
# actually
# then
# definitely
# back
# duplicate adverb in subtree: definitely
# also
# also
# fast
# always
# duplicate adverb in subtree: fast
# inside
# definitely
# definitely
# back
# duplicate adverb in subtree: definitely
# undoubtedly
# actually
# definitely
# duplicate adjective in subtree: other
# both
# just
# unfortunately
# too
# always
# well
# here
# probably
# always
# always
# always
# always
# here
# duplicate adverb in subtree: always
# probably
# back
# duplicate adverb in subtree: probably
# still
# still
# equally
# especially
# duplicate adverb in subtree: equally
# likely
# back
# duplicate adverb in subtree: likely
# much
# also
# though
# mostly
# so
# here
# basically
# maybe
# back
# here
# probably
# back
# duplicate adverb in subtree: probably
# again
# much
# even
# well
# duplicate adverb in subtree: even
# here
# definitely
# back
# duplicate adverb in subtree: definitely
# also
# sometimes
# however
# now
# only
# here
# duplicate adverb in subtree: only
# why
# so
# basically
# also
# so
# so
# also
# also
# across
# simply
# literally
# out
# so
# otherwise
# also
# here
# only
# out
# so
# why
# duplicate adverb in subtree: so
# always
# probably
# duplicate adjective in subtree: large
# really
# of
# away
# though
# also
# honestly
# here
# now
# always
# typically
# too
# too
# usually
# off
# usually
# definitely
# though
# best
# there
# anyway
# now
# duplicate adjective in subtree: nice
# here
# just
# first
# third
# here
# before
# duplicate adverb in subtree: here
# well
# so
# there
# duplicate adverb in subtree: so
# honestly
# always
# back
# back
# however
# well
# though
# here
# also
# also
# really
# really
# so
# always
# apparently
# however
# also
# there
# too
# quickly
# so
# back
# since
# duplicate adverb in subtree: back
# now
# then
# really
# also
# though
# however
# there
# up
# so
# so
# usually
# only
# here
# so
# here
# better
# close
# more
# duplicate adverb in subtree: close
# here
# duplicate adverb in subtree: close
# usually
# though
# then
# though
# always
# too
# well
# back
# well
# only
# best
# duplicate adverb in subtree: only
# out
# definitely
# ...
# always
# back
# now
# here
# so
# also
# strange
# anyways
# duplicate adverb in subtree: strange
# nonetheless
# definitely
# well
# all
# well
# really
# truly
# there
# so
# most
# definitely
# duplicate adverb in subtree: most
# back
# duplicate adverb in subtree: most
# truly
# always
# there
# always
# first
# so
# back
# here
# just
# however
# definitely
# more
# duplicate adverb in subtree: definitely
# definitely
# definitely
# apparently
# still
# also
# too
# here
# now
# duplicate adverb in subtree: here
# also
# also
# too
# also
# so
# here
# really
# also
# unfortunately
# still
# later
# so
# overall
# so
# honestly
# why
# all
# really
# really
# long
# long
# also
# also
# now
# there
# ever
# all
# duplicate adjective in subtree: put
# back
# genuinely
# always
# just
# however
# truly
# even
# now
# here
# so
# just
# duplicate adverb in subtree: so
# so
# so
# also
# eventually
# probably
# then
# price(luckily
# always
# only
# there
# once
# back
# here
# now
# duplicate adverb in subtree: here
# definitely
# back
# duplicate adverb in subtree: definitely
# once
# defiantly
# overall
# even
# so
# definitely
# back
# duplicate adverb in subtree: definitely
# here
# now
# duplicate adverb in subtree: here
# next
# however
# definitely
# here
# duplicate adverb in subtree: definitely
# so
# basically
# even
# actually
# so
# how
# personally
# only
# duplicate adverb in subtree: personally
# hopefully
# here
# then
# definitely
# here
# duplicate adverb in subtree: definitely
# actually
# however
# here
# back
# duplicate adverb in subtree: here
# too
# so
# well
# down
# however
# really
# duplicate adjective in subtree: fantastic
# duplicate adjective in subtree: super
# now
# indeed
# surprisingly
# really
# too
# unfortunately
# also
# simply
# first
# actually
# also
# also
# also
# however
# all
# so
# late
# again
# always
# well
# usually
# also
# here
# back
# fortunately
# long
# also
# possibly
# since
# always
# here
# again
# duplicate adjective in subtree: dry
# here
# though
# duplicate adverb in subtree: here
# also
# perhaps
# here
# already
# duplicate adverb in subtree: here
# when
# there
# also
# inside
# duplicate adverb in subtree: also
# so
# either
# duplicate adverb in subtree: so
# now
# still
# duplicate adverb in subtree: now
# always
# too
# duplicate adverb in subtree: always
# always
# now
# however
# overall
# back
# however
# far
# sometimes
# sometimes
# really
# unfortunately
# highly
# however
# where
# there
# even
# far
# here
# also
# however
# also
# much
# so
# much
# however
# still
# really
# also
# now
# always
# sometimes
# then
# back
# really
# close
# always
# always
# all
# far
# maybe
# maybe
# simply
# duplicate adverb in subtree: maybe
# away
# here
# also
# additionally
# finally
# first
# also
# also
# too
# away
# also
# though
# also
# literally
# yet
# always
# also
# almost
# always
# duplicate adverb in subtree: almost
# there
# still
# there
# duplicate adjective in subtree: close
# definitely
# really
# just
# literally
# away
# duplicate adverb in subtree: literally
# also
# easily
# however
# sure
# also
# already
# really
# also
# here
# only
# duplicate adverb in subtree: here
# then
# so
# anyway
# here
# again
# duplicate adverb in subtree: here
# soon
# duplicate adverb in subtree: here
# better
# definitely
# overall
# apparently
# instantly
# also
# away
# so
# also
# also
# usually
# duplicate adverb in subtree: also
# out
# duplicate adverb in subtree: also
# importantly
# actually
# fast
# also
# back
# well
# again
# late
# also
# however
# duplicate adjective in subtree: vague
# back
# so
# also
# however
# away
# here
# before
# however
# also
# far
# either
# duplicate adverb in subtree: far
# however
# now
# anyhow
# next
# also
# again
# there
# eventually
# literally
# however
# overall
# always
# usually
# there
# duplicate adverb in subtree: usually
# so
# later
# even
# far
# also
# nearby
# duplicate adverb in subtree: also
# lastly
# however
# also
# too
# too
# longer
# far
# also
# even
# too
# late
# long
# then
# usually
# duplicate adverb in subtree: then
# next
# either
# also
# so
# definitely
# ever
# back
# back
# all
# now
# apparently
# still
# though
# duplicate adverb in subtree: still
# always
# ever
# always
# late
# always
# secondly
# finally
# so
# probably
# here
# always
# also
# back
# always
# still
# always
# always
# far
# just
# seriously
# so
# always
# duplicate adjective in subtree: bad
# also
# basically
# so
# well
# actually
# also
# usually
# duplicate adverb in subtree: also
# so
# definitely
# always
# definitely
# duplicate adjective in subtree: good
# maybe
# just
# just
# well
# duplicate adverb in subtree: just
# overall
# obviously
# there
# yet
# definitely
# definitely
# back
# duplicate adverb in subtree: definitely
# best
# though
# so
# once
# also
# however
# also
# much
# obviously
# definitely
# back
# duplicate adverb in subtree: definitely
# certainly
# always
# always
# even
# though
# maybe
# well
# duplicate adverb in subtree: maybe
# always
# always
# always
# always
# poorly
# well
# also
# still
# so
# ever
# inside
# really
# fast
# duplicate adverb in subtree: really
# also
# also
# here
# even
# actually
# definitely
# back
# duplicate adverb in subtree: definitely
# also
# maybe
# there
# duplicate adverb in subtree: maybe
# however
# also
# also
# hardly
# definitely
# still
# duplicate adverb in subtree: definitely
# usually
# also
# also
# here
# here
# however
# either
# maybe
# also
# always
# always
# always
# too
# duplicate adverb in subtree: always
# also
# just
# here
# basically
# duplicate adjective in subtree: fresh
# once
# certainly
# mmmm
# really
# always
# seriously
# here
# duplicate adverb in subtree: seriously
# too
# even
# all
# best
# finally
# so
# how
# duplicate adverb in subtree: so
# overall
# truly
# always
# usually
# also
# mostly
# also
# below
# sometimes
# all
# still
# always
# always
# always
# always
# here
# always
# so
# often
# duplicate adverb in subtree: so
# also
# how
# simply
# just
# always
# also
# too
# also
# however
# far
# also
# here
# too
# however
# here
# regardless
# still
# duplicate adverb in subtree: regardless
# also
# always
# duplicate adverb in subtree: also
# probably
# however
# so
# course
# also
# also
# always
# finally
# also
# always
# duplicate adverb in subtree: also
# always
# also
# there
# always
# also
# finally
# also
# duplicate adverb in subtree: finally
# quickly
# typically
# definitely
# always
# probably
# really
# well
# probably
# too
# now
# even
# duplicate adverb in subtree: now
# sometimes
# out
# though
# however
# definitely
# always
# where
# just
# too
# likely
# ,oh
# sometimes
# there
# duplicate adverb in subtree: sometimes
# duplicate adjective in subtree: better
# also
# then
# actually
# just
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# here
# now
# duplicate adverb in subtree: here
# occasionally
# here
# always
# here
# definitely
# again
# duplicate adverb in subtree: definitely
# simultaneously
# always
# then
# here
# also
# overall
# least
# forever
# also
# here
# also
# so
# much
# really
# so
# all
# quite
# maybe
# always
# where
# usually
# also
# harder
# so
# so
# again
# better
# duplicate adverb in subtree: again
# here
# definitely
# back
# duplicate adverb in subtree: definitely
# only
# once
# duplicate adverb in subtree: only
# also
# definitely
# so
# matter
# duplicate adverb in subtree: so
# so
# actually
# duplicate adverb in subtree: so
# off
# next
# there
# so
# then
# here
# much
# so
# now
# duplicate adverb in subtree: so
# only
# once
# duplicate adverb in subtree: only
# later
# though
# then
# always
# also
# well
# overall
# then
# just
# often
# either
# apparently
# here
# before
# duplicate adverb in subtree: here
# maybe
# back
# sadly
# much
# duplicate adverb in subtree: sadly
# just
# loud
# back
# again
# duplicate adverb in subtree: back
# all
# always
# wise
# still
# definitely
# here
# legitimately
# definitely
# back
# duplicate adverb in subtree: definitely
# here
# once
# duplicate adverb in subtree: here
# enough
# again
# before
# either
# unfortunately
# well
# maybe
# now
# now
# Traceback (most recent call last):
#   File "/Users/aurelio.prahara/anaconda3/envs/4045/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3441, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/cr/t5frx0313c365t1gjc3269bnl38nv3/T/ipykernel_57271/1109709320.py", line 2, in <module>
#     phrases_dict = [get_list_of_phrases(review['text']) for review in reviews_dict]
#   File "/var/folders/cr/t5frx0313c365t1gjc3269bnl38nv3/T/ipykernel_57271/1109709320.py", line 2, in <listcomp>
#     phrases_dict = [get_list_of_phrases(review['text']) for review in reviews_dict]
#   File "/Users/aurelio.prahara/Documents/y3s1-projects/CZ4045-project1/indicative_adjphr/_get_adj_phrases.py", line 77, in get_list_of_phrases
#     phrase_counts = Counter(phrases)
#   File "/Users/aurelio.prahara/Documents/y3s1-projects/CZ4045-project1/indicative_adjphr/_get_adj_phrases.py", line 21, in get_adjective_phrases
#     doc = nlp(text)
#   File "/Users/aurelio.prahara/anaconda3/envs/4045/lib/python3.9/site-packages/spacy/language.py", line 437, in __call__
#     doc = self.make_doc(text)
#   File "/Users/aurelio.prahara/anaconda3/envs/4045/lib/python3.9/site-packages/spacy/language.py", line 467, in make_doc
#     return self.tokenizer(text)
#   File "tokenizer.pyx", line 170, in spacy.tokenizer.Tokenizer.__call__
#   File "tokenizer.pyx", line 241, in spacy.tokenizer.Tokenizer._tokenize
#   File "tokenizer.pyx", line 323, in spacy.tokenizer.Tokenizer._attach_tokens
#   File "vocab.pyx", line 152, in spacy.vocab.Vocab.get
#   File "vocab.pyx", line 181, in spacy.vocab.Vocab._new_lexeme
#   File "/Users/aurelio.prahara/anaconda3/envs/4045/lib/python3.9/site-packages/spacy/lang/lex_attrs.py", line 177, in lower
#     def lower(string):
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/aurelio.prahara/anaconda3/envs/4045/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/aurelio.prahara/anaconda3/envs/4045/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/aurelio.prahara/anaconda3/envs/4045/lib/python3.9/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/aurelio.prahara/anaconda3/envs/4045/lib/python3.9/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/aurelio.prahara/anaconda3/envs/4045/lib/python3.9/inspect.py", line 1541, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/aurelio.prahara/anaconda3/envs/4045/lib/python3.9/inspect.py", line 1499, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/aurelio.prahara/anaconda3/envs/4045/lib/python3.9/inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/aurelio.prahara/anaconda3/envs/4045/lib/python3.9/inspect.py", line 755, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/Users/aurelio.prahara/anaconda3/envs/4045/lib/python3.9/posixpath.py", line 392, in realpath
#     path, ok = _joinrealpath(filename[:0], filename, {})
#   File "/Users/aurelio.prahara/anaconda3/envs/4045/lib/python3.9/posixpath.py", line 425, in _joinrealpath
#     newpath = join(path, name)
#   File "/Users/aurelio.prahara/anaconda3/envs/4045/lib/python3.9/posixpath.py", line 71, in join
#     def join(a, *p):
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /var/folders/cr/t5frx0313c365t1gjc3269bnl38nv3/T/ipykernel_57271/1109709320.py in <module>
#       1 # this cell will take some time to run
# ----> 2 phrases_dict = [get_list_of_phrases(review['text']) for review in reviews_dict]
#
# /var/folders/cr/t5frx0313c365t1gjc3269bnl38nv3/T/ipykernel_57271/1109709320.py in <listcomp>(.0)
#       1 # this cell will take some time to run
# ----> 2 phrases_dict = [get_list_of_phrases(review['text']) for review in reviews_dict]
#
# ~/Documents/y3s1-projects/CZ4045-project1/indicative_adjphr/_get_adj_phrases.py in get_list_of_phrases(text)
#      76         phrases = [text for sublist in phrases for text in sublist]
# ---> 77         phrase_counts = Counter(phrases)
#      78         return phrase_counts
#
# ~/Documents/y3s1-projects/CZ4045-project1/indicative_adjphr/_get_adj_phrases.py in get_adjective_phrases(text)
#      20
# ---> 21         doc = nlp(text)
#      22         phrases = []
#
# ~/anaconda3/envs/4045/lib/python3.9/site-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#     436         """
# --> 437         doc = self.make_doc(text)
#     438         if component_cfg is None:
#
# ~/anaconda3/envs/4045/lib/python3.9/site-packages/spacy/language.py in make_doc(self, text)
#     466             )
# --> 467         return self.tokenizer(text)
#     468
#
# tokenizer.pyx in spacy.tokenizer.Tokenizer.__call__()
#
# tokenizer.pyx in spacy.tokenizer.Tokenizer._tokenize()
#
# tokenizer.pyx in spacy.tokenizer.Tokenizer._attach_tokens()
#
# vocab.pyx in spacy.vocab.Vocab.get()
#
# vocab.pyx in spacy.vocab.Vocab._new_lexeme()
#
# ~/anaconda3/envs/4045/lib/python3.9/site-packages/spacy/lang/lex_attrs.py in lower(string)
#     176
# --> 177 def lower(string):
#     178     return string.lower()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/envs/4045/lib/python3.9/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2060                         # in the engines. This should return a list of strings.
# -> 2061                         stb = value._render_traceback_()
#    2062                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~/anaconda3/envs/4045/lib/python3.9/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2061                         stb = value._render_traceback_()
#    2062                     except Exception:
# -> 2063                         stb = self.InteractiveTB.structured_traceback(etype,
#    2064                                             value, tb, tb_offset=tb_offset)
#    2065
#
# ~/anaconda3/envs/4045/lib/python3.9/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1365         else:
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#
# ~/anaconda3/envs/4045/lib/python3.9/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1265         if mode in self.verbose_modes:
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#
# ~/anaconda3/envs/4045/lib/python3.9/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1122         """Return a nice text document describing the traceback."""
#    1123
# -> 1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1125                                                                tb_offset)
#    1126
#
# ~/anaconda3/envs/4045/lib/python3.9/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~/anaconda3/envs/4045/lib/python3.9/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %% [markdown]
# we can then get the most common phrases. this is where the fun begins

# %%
most_common_phrases = [counter.most_common(5) for counter in phrases_dict]
most_common_phrases

# %% [markdown]
# since this does not show any good results as they are not indicative of anything, we look into TF-IDF

# %%
# get the most common phrases from all the datasets
all_phrases = dict(sum(phrases_dict, Counter()))
all_phrases
# Out:
# {'very pleased': 47,
#  'always good always good always good ': 15,
#  'just typical': 1,
#  'just average': 13,
#  'also fantastic also fantastic also fantastic also fantastic ': 1,
#  'at least': 75,
#  'how good': 44,
#  'how delicious': 11,
#  'very good': 620,
#  'very friendly': 366,
#  'really good': 453,
#  'very prompt': 5,
#  'even fewer': 1,
#  'real good': 6,
#  'too much': 193,
#  'pretty decent': 57,
#  'no better': 9,
#  'pretty good': 437,
#  'most recent': 34,
#  'pretty average': 9,
#  'way friendlier': 1,
#  'exceptionally good': 4,
#  'much better': 206,
#  'extremely greasy': 3,
#  'very empty': 2,
#  'enough large': 9,
#  'barely hot': 2,
#  'extremely attentive': 8,
#  'very busy': 84,
#  'too many': 70,
#  'super busy': 30,
#  'really nice': 125,
#  'so excited': 46,
#  'too low': 2,
#  'more interested': 9,
#  'very nice': 380,
#  'too busy': 71,
#  'how busy': 32,
#  'just wonderful': 5,
#  'pretty awesome': 16,
#  'ridiculously good': 4,
#  'pretty surprisingly darn': 1,
#  'just sad': 5,
#  'very spacious': 16,
#  'all exceptional all exceptional ': 1,
#  'very reasonable': 106,
#  'very marginal': 1,
#  'pretty empty': 13,
#  'always friendly always friendly ': 19,
#  'decent(not worth decent(not worth decent(not worth decent(not worth ': 1,
#  'very disappointing': 32,
#  'all lumpy': 1,
#  'very perticular': 1,
#  'so bizarre': 1,
#  'very expensive': 17,
#  'very loud': 16,
#  'just ok': 47,
#  'definitely worth definitely worth ': 9,
#  'really small': 7,
#  'very least': 11,
#  'less complacent': 1,
#  'pleasantly surprised': 83,
#  'just ok just ok just ok ': 3,
#  'very overpriced': 6,
#  'very average': 15,
#  'mostly attentive mostly attentive mostly attentive mostly attentive ': 1,
#  'really sure': 8,
#  'so great': 51,
#  'on great': 1,
#  'very comfortable': 40,
#  'at best': 29,
#  'really plentiful': 1,
#  'very disappointing!,this': 1,
#  'that good': 40,
#  'how wonderful': 10,
#  'pretty hard': 6,
#  'very large': 41,
#  'little odd': 5,
#  'maybe few': 1,
#  'very crunchy': 4,
#  'often good': 1,
#  'very attentive': 100,
#  'very rushed': 8,
#  'super friendly': 136,
#  'super loud': 3,
#  'so loud': 10,
#  'fairly quick': 10,
#  'quite good': 64,
#  'very saturated': 1,
#  'all worth': 10,
#  'very picky': 16,
#  'how accurate': 1,
#  'very oily': 3,
#  'fairly speedy': 2,
#  'very happy': 70,
#  'very tasty': 135,
#  'very kid': 1,
#  'so good': 284,
#  'fairly poor': 1,
#  'really busy': 33,
#  'only friendly': 1,
#  'always huge always huge ': 1,
#  'so big': 15,
#  'so many': 226,
#  'most specific': 1,
#  'certainly healthy': 1,
#  'great dry': 1,
#  'more concerned': 8,
#  'as many': 22,
#  'more accurate': 2,
#  'always prompt always prompt ': 3,
#  'very dark': 10,
#  'how dark': 1,
#  'consistently delicious': 7,
#  'better good': 1,
#  'so addictive': 3,
#  'how small': 6,
#  'too loud': 18,
#  'well prepared': 17,
#  'sometimes cold sometimes cold sometimes cold sometimes cold sometimes cold ': 1,
#  'sometimes hot': 1,
#  'very again inconsistent': 1,
#  'generally sub generally sub generally sub generally sub ': 1,
#  'enough lucky': 20,
#  'quite full': 3,
#  'too bit much': 1,
#  'extremely fresh': 7,
#  'quite fast': 2,
#  'slightly cheaper': 1,
#  'really fresh': 5,
#  'pretty busy': 25,
#  'quite nice': 12,
#  'everywhere albeit same': 1,
#  'that bad': 26,
#  'really bad': 33,
#  'really friendly': 40,
#  'very small': 70,
#  'very enjoyable': 15,
#  'extremely disappointed': 18,
#  'very bad': 26,
#  'always quick always quick ': 5,
#  'really impressed': 21,
#  'just regular': 1,
#  'quite modern': 2,
#  'always courteous always courteous ': 4,
#  'loosely packed': 1,
#  'too chewy': 3,
#  'still slow': 1,
#  'more skilled': 1,
#  'more additional': 1,
#  'as just satisfying': 1,
#  'always busy': 2,
#  'how hungry': 5,
#  'most shameful': 1,
#  'strictly japanese': 1,
#  'somewhat modern': 1,
#  'really tough': 4,
#  'how much': 89,
#  'how many': 57,
#  'partly due': 1,
#  'just shocked': 1,
#  'more expensive': 57,
#  'very big': 25,
#  'very limited': 24,
#  'very convenient': 22,
#  'pretty small': 23,
#  'pretty common': 4,
#  'pretty thin': 5,
#  'very appealing': 4,
#  'very fresh': 76,
#  'quite small': 18,
#  'even busy': 12,
#  'quite empty': 3,
#  'that big': 16,
#  'so fresh': 46,
#  'quite large': 20,
#  'neatly furnished': 1,
#  'slightly upscale': 1,
#  'much thinner': 2,
#  'only available': 6,
#  'that great': 41,
#  'too all bad': 1,
#  'quite impressive': 6,
#  'so worth': 20,
#  'most consistent': 2,
#  'pretty extensive': 4,
#  'definitely different definitely different ': 1,
#  'pretty still good': 2,
#  'also delicious also delicious ': 9,
#  'really loud': 1,
#  'very little': 57,
#  'also full also full ': 1,
#  'really mushy': 1,
#  'quite busy': 16,
#  'quite reasonable': 6,
#  'actually good actually good ': 2,
#  'more personal': 2,
#  'usually ready usually ready ': 1,
#  'very different': 16,
#  'all fresh all fresh ': 1,
#  'as extensive': 2,
#  'really grouchy': 1,
#  'just great': 11,
#  'too salty': 54,
#  'so moist': 4,
#  'very irritating': 1,
#  'too small': 27,
#  'very high': 17,
#  'quite economical': 1,
#  'very sullen': 1,
#  'too late': 16,
#  'enough big': 16,
#  'slightly uncomfortable': 3,
#  'how insulting': 2,
#  'very uncomfortable': 8,
#  'probably better probably better ': 2,
#  'of mean': 1,
#  'extremely yet efficient': 1,
#  'all surprised': 1,
#  'so tasty': 23,
#  'disappointed!,the good': 1,
#  'very low': 15,
#  'as impressive': 3,
#  'definitely worth': 39,
#  'extremely slimy': 1,
#  'certainly good': 1,
#  'more solid': 4,
#  'that much': 9,
#  'seemingly unhappy': 1,
#  'surprisingly busy': 1,
#  'really yummy': 8,
#  'always fresh': 14,
#  'there decent': 1,
#  'much bigger': 8,
#  'so hard': 24,
#  'so already full': 1,
#  'kill!,pleasantly surprised': 1,
#  'of nice': 2,
#  'extremely nice': 27,
#  'very few': 29,
#  'pretty sure': 35,
#  'very surprised': 9,
#  'as much': 47,
#  'very spongy': 1,
#  'too cheap': 3,
#  'as poor': 1,
#  'totally disappointed': 4,
#  'really inconsistent': 1,
#  'even better': 57,
#  'around worst': 1,
#  'pretty old': 3,
#  'late cold': 1,
#  'just right': 38,
#  'more fresh': 9,
#  'especially great': 4,
#  'so nice': 88,
#  'too long': 30,
#  'where annoyed': 1,
#  'pretty tasty': 29,
#  'also great also great ': 11,
#  'even apologetic': 3,
#  'very consistent': 8,
#  'as good': 110,
#  'very orangey': 1,
#  'very clean': 189,
#  'very best': 13,
#  'of annoying': 3,
#  'consistently good': 33,
#  'very delicious': 53,
#  'all empty all empty all empty all empty ': 1,
#  'consistently decent': 2,
#  'even close': 11,
#  'always dirty always dirty ': 3,
#  'too exciting': 2,
#  'enough good': 50,
#  'fatty hard': 1,
#  'too bad': 110,
#  'almost offensive': 1,
#  'damn good': 13,
#  'slightly spicy': 4,
#  'never equal': 1,
#  'very hefty': 2,
#  'very generous': 33,
#  'very hot': 22,
#  'temp(not frozen': 1,
#  'as just good': 22,
#  'fairly fresh': 1,
#  'much overall better': 1,
#  'as just easy': 1,
#  'always friendly': 12,
#  'very simple': 23,
#  'very complex': 1,
#  'so salty': 8,
#  'usually overwhelming': 1,
#  'too sweet': 61,
#  'really wrong': 2,
#  'of soggy': 2,
#  'so glad': 100,
#  'so polite': 5,
#  'so just much': 2,
#  'severly understaffed': 1,
#  'still good still good still good still good still good ': 1,
#  'very very poor': 2,
#  'most disappointing': 9,
#  'much more': 55,
#  'extremely brown': 1,
#  'so dirty': 2,
#  'so blase': 1,
#  'all fine all fine ': 1,
#  'always great always great ': 13,
#  'super cheap': 10,
#  'so kind': 22,
#  'so delicious': 51,
#  'really tasty': 22,
#  'always hot': 4,
#  'very slow': 23,
#  'very polite': 28,
#  'exponentially better': 1,
#  'very solid': 5,
#  'super efficient': 1,
#  'fully functional': 2,
#  'very disappointed': 63,
#  'once then more': 1,
#  'always wrong always wrong always wrong ': 1,
#  'all sticky all sticky ': 1,
#  'totally disgusted': 3,
#  'always minimum always minimum ': 1,
#  'definitely better': 4,
#  'more detailed': 4,
#  'probably annoyed': 1,
#  'fully satisfied': 2,
#  'so frustrating': 3,
#  'pretty obvious': 1,
#  'anywhere close': 5,
#  'as busy': 4,
#  'so bitter': 1,
#  'very sweet': 46,
#  'really sweet': 9,
#  'pretty rude': 4,
#  'pretty accurate': 4,
#  'extremely courteous': 4,
#  'too way sweet': 3,
#  'ie hot': 1,
#  'extremely specific': 1,
#  'somewhat tasty': 1,
#  'surprisingly good': 12,
#  'ahoy iced': 1,
#  'less expensive': 18,
#  'of old': 2,
#  'super excited': 11,
#  'very just disappointed': 1,
#  'well worth': 79,
#  'very quick': 25,
#  'so weak': 4,
#  'really damaging': 1,
#  'more important': 8,
#  'extremely slow': 12,
#  'literally last': 1,
#  'even bussy': 1,
#  'kinda excited': 1,
#  'neither hot': 1,
#  'too way much': 28,
#  'very serious': 2,
#  'even nice': 1,
#  'very hard': 15,
#  'very welcoming': 26,
#  'extremely unprofessional': 6,
#  'any ready': 1,
#  'super fast': 19,
#  'pretty complicated': 1,
#  'actually better actually better actually better ': 1,
#  'really excessive': 1,
#  'easily accessible': 4,
#  'earlier where close': 1,
#  'very strange': 6,
#  'even good': 2,
#  'so used': 3,
#  'so few': 2,
#  'hard dark dry': 1,
#  'extremely friendly': 47,
#  'just enough': 12,
#  'less heavy': 2,
#  'nearly empty': 5,
#  'about same': 4,
#  'overly friendly': 3,
#  'super welcoming': 1,
#  'terribly wide': 1,
#  'so special': 4,
#  'where fresh': 1,
#  'also dry': 1,
#  'all clean': 2,
#  'over cooked': 35,
#  'too oily': 11,
#  'just same': 1,
#  'pretty still awesome': 1,
#  'so impressed': 20,
#  'so tender': 16,
#  'much larger': 11,
#  'how bright': 1,
#  'well lit': 4,
#  'indescribably rich': 1,
#  'really fun': 9,
#  'quite bare': 1,
#  'only nice': 1,
#  'very exciting': 3,
#  'very similar': 20,
#  'very extensive': 6,
#  'as just impressive': 1,
#  'completely disappointed': 4,
#  'so much': 173,
#  'so even busy': 1,
#  'yet fragrant': 1,
#  'so fun': 7,
#  'really encouraged': 1,
#  'really disappointed': 21,
#  'really salty': 2,
#  'super trendy': 2,
#  'aesthetically pleasing': 5,
#  'that hungry': 6,
#  'super ecstatic': 1,
#  'how beautiful': 6,
#  'very acidic': 1,
#  'most favorite': 5,
#  'enough super big': 1,
#  'so different': 4,
#  'well balanced': 12,
#  'overly salty': 12,
#  'really surprising': 1,
#  'absolutely amazing': 42,
#  'very fancy': 5,
#  'so beautiful': 7,
#  'very affordable': 19,
#  'quite bland': 6,
#  'mostly starchy': 1,
#  'of small': 7,
#  'very dry': 18,
#  'very corporate': 1,
#  'very insensitive': 2,
#  'honestly fair': 1,
#  'culturally eclectic': 1,
#  'super attentive': 7,
#  'very likable': 2,
#  'more enjoyable': 7,
#  'incredibly tasty': 2,
#  'very popular': 14,
#  'totally brilliant': 1,
#  'very modern': 19,
#  'more straightforward': 1,
#  'so disappointed': 29,
#  'pretty positive': 4,
#  'so rude': 18,
#  'mouthwateringly perfect': 1,
#  'so refreshing': 9,
#  'highly recommend': 12,
#  'surprisingly crunchy': 1,
#  'exceptionally friendly': 7,
#  'very helpful': 120,
#  'so little': 11,
#  'overall good': 4,
#  'very dense': 4,
#  'completely disorganized': 1,
#  'very relaxing': 32,
#  'quite slow': 8,
#  'very smiley': 1,
#  'extremely full': 1,
#  'pretty disappointed': 11,
#  'pretty romantic': 1,
#  'too impressed': 5,
#  'pretty disgusting': 4,
#  'very unacceptable': 1,
#  'very very good': 11,
#  'very full': 10,
#  'half full': 6,
#  'maybe loud': 1,
#  'just okay': 24,
#  'way overcrowded': 1,
#  'so full': 15,
#  'pretty packed': 4,
#  'quite new': 2,
#  'extremely instead dry': 1,
#  'very fun': 9,
#  'most popular': 11,
#  'very patient': 20,
#  'really great': 61,
#  'actually great actually great actually great actually great ': 1,
#  'particularly flavourful': 1,
#  'completely underwhelming': 2,
#  'enough moist': 1,
#  'absolutely delicious': 54,
#  'all nice': 3,
#  'very difficult': 16,
#  'rather small': 6,
#  'more suited': 2,
#  'so juicy': 8,
#  'basically bibimbap': 1,
#  'usually lively': 1,
#  'pretty low': 8,
#  'most simplistic': 1,
#  'extremely difficult': 5,
#  'how attractive': 1,
#  'no different': 9,
#  'also excellent also excellent ': 7,
#  'almost sushi': 1,
#  'too definitely much': 1,
#  'super tender': 5,
#  'very much': 3,
#  'never now disappointed': 1,
#  'slightly more': 5,
#  'generally good generally good generally good ': 1,
#  'unfortunatwly undercooked': 1,
#  'choros(not bad': 1,
#  'deathly sweet': 1,
#  'of slow': 3,
#  'so sweet': 41,
#  'pretty plain': 3,
#  'plain white': 3,
#  'so bland': 5,
#  'very salty': 19,
#  'of strange': 2,
#  'all friendly all friendly ': 1,
#  'absolutely fantastic': 4,
#  'very knowledgeable': 56,
#  'very very special': 1,
#  'well least': 1,
#  'extremely mediocre': 1,
#  'quite disappointing': 10,
#  'very tiny': 6,
#  'very thick': 15,
#  'just disappointed': 4,
#  'very curious': 1,
#  'incredibly friendly': 15,
#  'anywhere worth': 1,
#  'just flat': 1,
#  'too packed': 2,
#  'just glad': 6,
#  'how different': 2,
#  'pretty cool': 29,
#  'too crowded': 23,
#  'too expensive': 19,
#  'super cool': 15,
#  'extremely inebriated': 1,
#  'so pissed': 2,
#  'most shit': 1,
#  'very relaxed': 7,
#  'pretty spacious': 5,
#  'however many': 2,
#  'practically dead': 1,
#  'impossibly thin': 1,
#  'too way spicy': 2,
#  'too way tiny': 1,
#  'so hot': 11,
#  'pretty upscale': 1,
#  'under experienced': 1,
#  'more approachable': 1,
#  'very strong': 8,
#  'over crowded': 2,
#  'pretty dark': 2,
#  'too pricey': 11,
#  'relatively high': 4,
#  'all dark': 1,
#  'seemingly sophisticated': 1,
#  'pretty attractive': 2,
#  'extra pissed': 1,
#  'super rude': 7,
#  'incredibly good': 3,
#  'actually lucky actually lucky actually lucky actually lucky ': 1,
#  'how cozy': 1,
#  'pretty steep': 4,
#  'very sexy': 2,
#  'pretty similar': 4,
#  'pretty friendly': 5,
#  'very crowded': 15,
#  'enough loud': 4,
#  'fairly empty': 2,
#  'pretty standard': 27,
#  'rather loud': 1,
#  'more delicious': 3,
#  'there damn too dark': 1,
#  'as honest': 2,
#  'more busy': 1,
#  'extremely fun': 1,
#  'quite dark': 2,
#  'really difficult': 5,
#  'pretty buss': 1,
#  'definitely decorative': 1,
#  'even more': 10,
#  'though pretentious': 1,
#  'so warm': 5,
#  'really bright': 4,
#  'very dim': 2,
#  'enough friendly': 12,
#  'so small': 13,
#  'how nice': 11,
#  'kinda cool': 3,
#  'as sophisticated': 1,
#  'too young': 2,
#  'too drunk': 1,
#  'more dynamic': 1,
#  'really casual': 1,
#  'really ridiculous': 2,
#  'really uncomfortable': 2,
#  'more like': 3,
#  'enough old': 3,
#  'somewhat short': 1,
#  'practically empty': 4,
#  'really drunk': 1,
#  'most great': 1,
#  'very famous': 1,
#  'much friendlier': 2,
#  'only few': 34,
#  'too partied': 1,
#  'very key': 1,
#  'very quaint': 2,
#  'very surprising': 1,
#  'little more': 9,
#  'almost empty': 9,
#  'very danceable': 1,
#  'so danceable': 1,
#  'so grand': 1,
#  'how rude': 7,
#  'completely disgusted': 1,
#  'completely bad': 1,
#  'too hard': 13,
#  'very thorough': 21,
#  'even worse': 20,
#  'very poor': 23,
#  'pretty helpful': 1,
#  'so bad': 71,
#  'really horrible': 2,
#  'that worried': 1,
#  'sparkly all clean': 1,
#  'how dirty': 5,
#  'only good': 3,
#  'sh*tty est': 1,
#  'just terrible': 5,
#  'very careful': 4,
#  'glacially slow': 2,
#  'even when busy': 1,
#  'so happy': 73,
#  'completely detailed': 1,
#  'most horrible': 3,
#  'really pleasant': 3,
#  'meticulously clean': 1,
#  'as clean': 9,
#  'definitely best': 3,
#  'terribly wrong': 2,
#  'even comparable': 1,
#  'pretty sloppy': 1,
#  'pretty clean': 12,
#  'just dusty': 1,
#  'pretty substandard': 1,
#  'enough expensive': 1,
#  'very narrow': 4,
#  'pretty thorough': 1,
#  'always double': 2,
#  'very kind': 26,
#  'pretty satisfied': 2,
#  'how long': 6,
#  'quite frustrated': 1,
#  'much higher': 10,
#  'quite disappointed': 9,
#  'pretty shiny': 1,
#  'very dirty': 5,
#  'still wet still wet still wet still wet ': 2,
#  'really mad': 4,
#  'fast clean': 1,
#  'most basic': 3,
#  'very pricey': 3,
#  'really desperate': 1,
#  'obviously distressing': 1,
#  'always immaculate always immaculate ': 1,
#  'still dirty still dirty still dirty still dirty still dirty ': 2,
#  'any better': 7,
#  'that dirty': 1,
#  'always impressed always impressed ': 2,
#  'how quick': 4,
#  'overly aggressive': 2,
#  'very crappy': 1,
#  'super dirty': 4,
#  'as great': 11,
#  'anywhere else!,terrible': 1,
#  'only concerned': 2,
#  'more noticeable': 1,
#  'extremely valuable': 1,
#  'obviously valuable': 1,
#  'just wet': 1,
#  'still dirty': 1,
#  'as just dirty': 1,
#  'how disappointed': 3,
#  'very personable': 12,
#  'unfortunately knowledgable': 1,
#  'as smooth': 3,
#  'clearly visible': 2,
#  'otherwise physical': 1,
#  'also wonderful also wonderful ': 4,
#  'really hard': 7,
#  'extremely clean': 10,
#  'extremely accomodating': 1,
#  'so thankful': 20,
#  'super nice': 75,
#  'very peaceful': 6,
#  'completely relaxed': 4,
#  'very professional': 71,
#  'incredibly disappointed': 2,
#  'very serene': 1,
#  'extremely competent': 1,
#  'always able always able ': 1,
#  'about half': 3,
#  'least pricey': 1,
#  'super relaxing': 2,
#  'really weak': 1,
#  'super easy': 9,
#  'too chatty': 2,
#  'so relaxing': 5,
#  'very gracious': 3,
#  'most expert': 1,
#  'really long': 7,
#  'personally friendly': 1,
#  'extremely dry': 9,
#  'absolutely glowing': 1,
#  'so knowledgeable': 6,
#  'very concerned': 2,
#  'very pleasant': 35,
#  'highly impressed': 3,
#  'even easier': 1,
#  'so enjoyable': 3,
#  'quite amazing': 2,
#  'largely organic': 1,
#  'more positive': 4,
#  'incredibly personable': 2,
#  'less clinical': 1,
#  'extremely lovely': 1,
#  'more reasonable': 9,
#  'still sure': 1,
#  'so atmosphere- relaxing': 1,
#  'most relaxing': 2,
#  'usually lavender': 1,
#  'all professional': 1,
#  'very hygienic': 2,
#  'really fast': 3,
#  'incredibly strong': 1,
#  'overall really just disappointing': 1,
#  'somewhat nitpicky': 1,
#  'more stressed': 1,
#  'very awkward': 6,
#  'very annoying': 12,
#  'too high': 20,
#  'yet more energized': 1,
#  'so relaxed': 5,
#  'very misled': 1,
#  'so positive': 2,
#  'extremely kind': 4,
#  'more relaxing': 2,
#  'most amazing': 18,
#  'always courteous': 1,
#  'so welcoming': 10,
#  'really fantastic': 1,
#  'mostly big': 1,
#  'very easy': 23,
#  'somewhat picky': 1,
#  'consistently great': 4,
#  'most beautiful': 9,
#  'all organic all organic all organic all organic ': 1,
#  'ever first': 2,
#  'totally hilarious': 1,
#  'very technically talented': 1,
#  'very lucky': 4,
#  'very light': 8,
#  'so comfortable': 13,
#  'pretty relaxing': 1,
#  'so comforting': 8,
#  'really mixed': 1,
#  'actually lovely': 1,
#  'definitely conducive': 1,
#  'super funny': 4,
#  'so smart': 2,
#  'extremely relaxing': 2,
#  'thoroughly displeased': 1,
#  'super relaxed': 3,
#  'technically great': 1,
#  'more clinical': 1,
#  'extremely professional': 9,
#  'super knowledgeable': 6,
#  'also certified ': 1,
#  'currently pregnant currently pregnant currently pregnant ': 1,
#  'very rude': 49,
#  'completely new': 4,
#  'how important': 4,
#  'as simple': 4,
#  'totally comfortable': 3,
#  'really worth': 9,
#  'very chilly': 1,
#  'pretty big': 36,
#  'absolutely best': 5,
#  'more relaxed': 3,
#  'most experienced': 2,
#  'most generous': 1,
#  'extremely busy': 15,
#  'pretty gross': 4,
#  'gruellingly slow': 1,
#  'extra busy': 1,
#  'enough adequate': 1,
#  'less familiar': 2,
#  'just standard': 1,
#  'more popular': 11,
#  'likely more': 1,
#  'considerably hotter': 1,
#  'most important': 21,
#  'how popular': 1,
#  'deathly spicy': 1,
#  'painfully long': 2,
#  'absolutely massive': 2,
#  'so huge': 7,
#  'so convinced': 1,
#  'pretty true': 1,
#  'pretty full': 17,
#  'never again!!!!,used': 1,
#  'always busy always busy always busy ': 7,
#  'pretty annoying': 3,
#  'really disorganized': 1,
#  'pretty clear': 3,
#  'extremely great': 1,
#  'just jealous': 1,
#  'just curious': 1,
#  'particularly small': 1,
#  'completely different': 16,
#  'mildly gross': 1,
#  'how just much': 1,
#  'mildly ill': 1,
#  'delightfully tacky': 1,
#  'really actually good': 1,
#  'more uye': 1,
#  'pretty bad': 24,
#  'so familiar': 2,
#  'ever possible': 1,
#  'super convenient': 6,
#  'always hot always hot always hot ': 1,
#  'fairly quiet': 1,
#  'very overall impressed': 2,
#  'super quick': 5,
#  'marginally only better': 1,
#  'very experienced': 1,
#  'totally worth': 33,
#  'super clean': 35,
#  'extremely tasty': 5,
#  'also nice also nice ': 2,
#  'never present': 1,
#  'pretty hesitant': 2,
#  'pretty worth': 1,
#  'super large': 1,
#  'so best': 2,
#  'well sauced': 1,
#  'pretty impressed': 8,
#  'most welcoming': 3,
#  'pretty basic': 7,
#  'so long': 7,
#  'never horrible': 2,
#  'never great': 1,
#  'how hot': 5,
#  'really undercooked': 2,
#  'pretty huge': 3,
#  'that so hot': 1,
#  'quite impressed': 13,
#  'somewhat dissatisfying': 1,
#  'just gross': 3,
#  'again gross': 1,
#  'actually gross actually gross ': 1,
#  'barely warm': 6,
#  'pretty loud': 4,
#  'usually good': 3,
#  'well mixed': 1,
#  'too slimy': 1,
#  'enough hot': 7,
#  'always good always good always good always good always good ': 2,
#  'never consistent': 1,
#  'definitely great': 3,
#  'pretty slow': 6,
#  'just amazing': 14,
#  'as hot': 3,
#  'somewhat slow': 1,
#  'definitely fresh definitely fresh definitely fresh definitely fresh ': 1,
#  'pretty rammed': 1,
#  'as strong': 1,
#  'just electric': 1,
#  'as far': 1,
#  'so ugly': 2,
#  'very disgusting': 1,
#  'always friendly always friendly always friendly ': 7,
#  'super weird': 1,
#  'under sauced': 1,
#  'completely unimpressed': 1,
#  'super hungry': 9,
#  'too good': 17,
#  'pretty enjoyable': 2,
#  'horribly sick': 2,
#  'otherwise horrible': 1,
#  'probably close': 1,
#  'already full already full already full ': 1,
#  'almost inedible': 3,
#  'so elegant': 1,
#  'constantly great': 1,
#  'only fair': 1,
#  'here facial': 1,
#  'atmosphere- relaxing': 1,
#  'super personable': 3,
#  'super gentle': 4,
#  'absolutely incredible': 5,
#  'very first': 13,
#  'completely worth': 3,
#  'absolutely wonderful': 11,
#  'very courteous': 15,
#  'very tight': 4,
#  'real happy': 1,
#  'very shady': 1,
#  'as just pricey': 1,
#  'very next': 8,
#  'quite pricey': 2,
#  'so easy': 13,
#  'notch!!!,absolutely lovely': 1,
#  'so worried': 5,
#  'well organized': 6,
#  'of uncomfortable': 1,
#  'too way pricey': 1,
#  'incredibly rude': 5,
#  'super disappointing': 3,
#  'ridiculously expensive': 2,
#  'yet so gentle': 1,
#  'by close': 6,
#  'as twice much': 3,
#  'always happy always happy always happy always happy ': 2,
#  'plain mean': 1,
#  'very unkind': 1,
#  'very unpleasant': 6,
#  'totally beautiful': 2,
#  'more pampering': 1,
#  'completely processional': 1,
#  'completely comfortable': 2,
#  'super sweet': 24,
#  'so gentle': 8,
#  'so pleased': 11,
#  'extremely knowledgeable': 9,
#  'whatsoever pushy': 1,
#  'genuinely interested': 3,
#  'so refreshed': 1,
#  'quite serene': 1,
#  'extremely polite': 2,
#  'so clean': 15,
#  'more magical': 1,
#  'absolutely awesome': 3,
#  'reallllly hard': 1,
#  'super smooth': 3,
#  'super interested': 1,
#  'very cranky': 1,
#  'most memorable': 2,
#  'how tight': 2,
#  'just fantastic': 5,
#  'so professional': 6,
#  'as attentive': 3,
#  'incredibly relaxing': 1,
#  'as young': 1,
#  'objectively better objectively better ': 1,
#  'mildly solicitous': 1,
#  'too hot': 15,
#  'deeply disappointed': 1,
#  'extraordinarily better': 1,
#  'extremely gifted': 1,
#  'so creative': 1,
#  'always bad always bad always bad ': 1,
#  'pretty shitty': 1,
#  'too far much': 5,
#  'very appropriate': 1,
#  'surprisingly very busy': 1,
#  'really comfy': 2,
#  'somewhat worried': 1,
#  'so needless': 3,
#  'very special': 6,
#  'equally great': 4,
#  'absolutely disappointed': 1,
#  'absolutely ridiculous': 5,
#  'incredibly attentive': 2,
#  'very beautiful': 8,
#  'super fresh': 17,
#  'super juicy': 6,
#  'slightly gritty': 2,
#  'so friendly': 71,
#  'very bland': 22,
#  'too lackluster': 1,
#  'most successful': 2,
#  'so cheap': 14,
#  'apparently amazing': 1,
#  'as big': 16,
#  'fairly clean': 6,
#  'more definitely genuine': 1,
#  'just delicious': 5,
#  'damn delicious': 1,
#  'all excellent all excellent all excellent all excellent ': 1,
#  'really cool': 34,
#  'perfectly pink': 1,
#  'very juicy': 10,
#  'perfectly prepared': 3,
#  ...}

# %%
common_phrases_list = [counter.most_common() for counter in phrases_dict]
common_phrases = [tuples for sublist in common_phrases_list for tuples in sublist]
common_phrases
# Out:
# [('very good', 9),
#  ('pretty good', 9),
#  ('really good', 7),
#  ('very friendly', 4),
#  ('very busy', 4),
#  ('very pleased', 3),
#  ('at least', 2),
#  ('too much', 2),
#  ('much better', 2),
#  ('too busy', 2),
#  ('very spacious', 2),
#  ('very large', 2),
#  ('very attentive', 2),
#  ('super friendly', 2),
#  ('so good', 2),
#  ('always good always good always good ', 1),
#  ('just typical', 1),
#  ('just average', 1),
#  ('also fantastic also fantastic also fantastic also fantastic ', 1),
#  ('how good', 1),
#  ('how delicious', 1),
#  ('very prompt', 1),
#  ('even fewer', 1),
#  ('real good', 1),
#  ('pretty decent', 1),
#  ('no better', 1),
#  ('most recent', 1),
#  ('pretty average', 1),
#  ('way friendlier', 1),
#  ('exceptionally good', 1),
#  ('extremely greasy', 1),
#  ('very empty', 1),
#  ('enough large', 1),
#  ('barely hot', 1),
#  ('extremely attentive', 1),
#  ('too many', 1),
#  ('super busy', 1),
#  ('really nice', 1),
#  ('so excited', 1),
#  ('too low', 1),
#  ('more interested', 1),
#  ('very nice', 1),
#  ('how busy', 1),
#  ('just wonderful', 1),
#  ('pretty awesome', 1),
#  ('ridiculously good', 1),
#  ('pretty surprisingly darn', 1),
#  ('just sad', 1),
#  ('all exceptional all exceptional ', 1),
#  ('very reasonable', 1),
#  ('very marginal', 1),
#  ('pretty empty', 1),
#  ('always friendly always friendly ', 1),
#  ('decent(not worth decent(not worth decent(not worth decent(not worth ', 1),
#  ('very disappointing', 1),
#  ('all lumpy', 1),
#  ('very perticular', 1),
#  ('so bizarre', 1),
#  ('very expensive', 1),
#  ('very loud', 1),
#  ('just ok', 1),
#  ('definitely worth definitely worth ', 1),
#  ('really small', 1),
#  ('very least', 1),
#  ('less complacent', 1),
#  ('pleasantly surprised', 1),
#  ('just ok just ok just ok ', 1),
#  ('very overpriced', 1),
#  ('very average', 1),
#  ('mostly attentive mostly attentive mostly attentive mostly attentive ', 1),
#  ('really sure', 1),
#  ('so great', 1),
#  ('on great', 1),
#  ('very comfortable', 1),
#  ('at best', 1),
#  ('really plentiful', 1),
#  ('very disappointing!,this', 1),
#  ('that good', 1),
#  ('how wonderful', 1),
#  ('pretty hard', 1),
#  ('little odd', 1),
#  ('maybe few', 1),
#  ('very crunchy', 1),
#  ('often good', 1),
#  ('very rushed', 1),
#  ('super loud', 1),
#  ('so loud', 1),
#  ('fairly quick', 1),
#  ('quite good', 1),
#  ('very saturated', 1),
#  ('all worth', 1),
#  ('very picky', 1),
#  ('how accurate', 1),
#  ('very oily', 1),
#  ('fairly speedy', 1),
#  ('very happy', 1),
#  ('very tasty', 1),
#  ('very kid', 1),
#  ('fairly poor', 1),
#  ('really busy', 1),
#  ('only friendly', 1),
#  ('always huge always huge ', 1),
#  ('so big', 1),
#  ('so many', 1),
#  ('most specific', 1),
#  ('certainly healthy', 1),
#  ('great dry', 1),
#  ('more concerned', 1),
#  ('as many', 1),
#  ('more accurate', 1),
#  ('always prompt always prompt ', 1),
#  ('very dark', 1),
#  ('how dark', 1),
#  ('consistently delicious', 1),
#  ('better good', 1),
#  ('so addictive', 1),
#  ('so good', 6),
#  ('much better', 5),
#  ('very nice', 4),
#  ('really good', 4),
#  ('very fresh', 4),
#  ('so fresh', 4),
#  ('pretty good', 3),
#  ('extremely fresh', 3),
#  ('very friendly', 3),
#  ('very small', 3),
#  ('really busy', 3),
#  ('too much', 3),
#  ('pretty decent', 2),
#  ('quite good', 2),
#  ('pretty busy', 2),
#  ('quite nice', 2),
#  ('so many', 2),
#  ('pleasantly surprised', 2),
#  ('quite small', 2),
#  ('very tasty', 2),
#  ('very good', 2),
#  ('that big', 2),
#  ('that great', 2),
#  ('quite busy', 2),
#  ('definitely worth', 2),
#  ('how small', 1),
#  ('too loud', 1),
#  ('well prepared', 1),
#  ('sometimes cold sometimes cold sometimes cold sometimes cold sometimes cold ',
#   1),
#  ('sometimes hot', 1),
#  ('very again inconsistent', 1),
#  ('generally sub generally sub generally sub generally sub ', 1),
#  ('enough lucky', 1),
#  ('quite full', 1),
#  ('too bit much', 1),
#  ('quite fast', 1),
#  ('slightly cheaper', 1),
#  ('really fresh', 1),
#  ('everywhere albeit same', 1),
#  ('that bad', 1),
#  ('really bad', 1),
#  ('really friendly', 1),
#  ('very enjoyable', 1),
#  ('extremely disappointed', 1),
#  ('very bad', 1),
#  ('always quick always quick ', 1),
#  ('really impressed', 1),
#  ('just regular', 1),
#  ('quite modern', 1),
#  ('always courteous always courteous ', 1),
#  ('loosely packed', 1),
#  ('too chewy', 1),
#  ('still slow', 1),
#  ('more skilled', 1),
#  ('more additional', 1),
#  ('as just satisfying', 1),
#  ('always busy', 1),
#  ('how hungry', 1),
#  ('most shameful', 1),
#  ('strictly japanese', 1),
#  ('very attentive', 1),
#  ('somewhat modern', 1),
#  ('really tough', 1),
#  ('how much', 1),
#  ('how many', 1),
#  ('partly due', 1),
#  ('just shocked', 1),
#  ('more expensive', 1),
#  ('very big', 1),
#  ('very limited', 1),
#  ('very convenient', 1),
#  ('pretty small', 1),
#  ('pretty common', 1),
#  ('pretty thin', 1),
#  ('very appealing', 1),
#  ('even busy', 1),
#  ('very happy', 1),
#  ('quite empty', 1),
#  ('quite large', 1),
#  ('neatly furnished', 1),
#  ('slightly upscale', 1),
#  ('always good always good always good ', 1),
#  ('much thinner', 1),
#  ('only available', 1),
#  ('too all bad', 1),
#  ('quite impressive', 1),
#  ('so worth', 1),
#  ('most consistent', 1),
#  ('pretty extensive', 1),
#  ('definitely different definitely different ', 1),
#  ('pretty still good', 1),
#  ('also delicious also delicious ', 1),
#  ('really loud', 1),
#  ('very little', 1),
#  ('also full also full ', 1),
#  ('really mushy', 1),
#  ('quite reasonable', 1),
#  ('actually good actually good ', 1),
#  ('very reasonable', 1),
#  ('more personal', 1),
#  ('usually ready usually ready ', 1),
#  ('very different', 1),
#  ('how busy', 1),
#  ('all fresh all fresh ', 1),
#  ('as extensive', 1),
#  ('really grouchy', 1),
#  ('just great', 1),
#  ('too salty', 1),
#  ('so moist', 1),
#  ('very irritating', 1),
#  ('too small', 1),
#  ('very high', 1),
#  ('quite economical', 1),
#  ('very sullen', 1),
#  ('too late', 1),
#  ('enough big', 1),
#  ('slightly uncomfortable', 1),
#  ('how insulting', 1),
#  ('very uncomfortable', 1),
#  ('at least', 1),
#  ('probably better probably better ', 1),
#  ('of mean', 1),
#  ('extremely yet efficient', 1),
#  ('all surprised', 1),
#  ('so tasty', 1),
#  ('disappointed!,the good', 1),
#  ('very low', 1),
#  ('as impressive', 1),
#  ('extremely slimy', 1),
#  ('certainly good', 1),
#  ('pretty empty', 1),
#  ('more solid', 1),
#  ('that much', 1),
#  ('seemingly unhappy', 1),
#  ('surprisingly busy', 1),
#  ('really yummy', 1),
#  ('always fresh', 1),
#  ('there decent', 1),
#  ('much bigger', 1),
#  ('so hard', 1),
#  ('so already full', 1),
#  ('kill!,pleasantly surprised', 1),
#  ('of nice', 1),
#  ('pretty good', 6),
#  ('really good', 3),
#  ('as good', 3),
#  ('pretty tasty', 2),
#  ('very disappointing', 2),
#  ('consistently good', 2),
#  ('very nice', 2),
#  ('very friendly', 2),
#  ('always friendly', 2),
#  ('very simple', 2),
#  ('so fresh', 2),
#  ('extremely nice', 1),
#  ('very few', 1),
#  ('pretty sure', 1),
#  ('pretty busy', 1),
#  ('so good', 1),
#  ('very surprised', 1),
#  ('as much', 1),
#  ('very spongy', 1),
#  ('too cheap', 1),
#  ('as poor', 1),
#  ('totally disappointed', 1),
#  ('really inconsistent', 1),
#  ('that big', 1),
#  ('so great', 1),
#  ('even better', 1),
#  ('around worst', 1),
#  ('definitely worth', 1),
#  ('pretty old', 1),
#  ('late cold', 1),
#  ('just right', 1),
#  ('more fresh', 1),
#  ('too busy', 1),
#  ('especially great', 1),
#  ('so nice', 1),
#  ('too long', 1),
#  ('really friendly', 1),
#  ('where annoyed', 1),
#  ('also great also great ', 1),
#  ('even apologetic', 1),
#  ('very consistent', 1),
#  ('very orangey', 1),
#  ('very clean', 1),
#  ('very best', 1),
#  ('very busy', 1),
#  ('of annoying', 1),
#  ('so many', 1),
#  ('very delicious', 1),
#  ('all empty all empty all empty all empty ', 1),
#  ('consistently decent', 1),
#  ('even close', 1),
#  ('always dirty always dirty ', 1),
#  ('too exciting', 1),
#  ('very expensive', 1),
#  ('enough good', 1),
#  ('fatty hard', 1),
#  ('too bad', 1),
#  ('almost offensive', 1),
#  ('damn good', 1),
#  ('slightly spicy', 1),
#  ('never equal', 1),
#  ('very hefty', 1),
#  ('very generous', 1),
#  ('very fresh', 1),
#  ('very hot', 1),
#  ('temp(not frozen', 1),
#  ('as just good', 1),
#  ('fairly fresh', 1),
#  ('much overall better', 1),
#  ('as just easy', 1),
#  ('very complex', 1),
#  ('so salty', 1),
#  ('too much', 1),
#  ('how much', 1),
#  ('usually overwhelming', 1),
#  ('very large', 1),
#  ('too sweet', 1),
#  ('much better', 1),
#  ('really wrong', 1),
#  ('of soggy', 1),
#  ('so glad', 1),
#  ('so polite', 1),
#  ('so just much', 1),
#  ('severly understaffed', 1),
#  ('still good still good still good still good still good ', 1),
#  ('very very poor', 1),
#  ('very reasonable', 1),
#  ('most disappointing', 1),
#  ('much more', 1),
#  ('extremely brown', 1),
#  ('so dirty', 1),
#  ('so blase', 1),
#  ('all fine all fine ', 1),
#  ('always great always great ', 1),
#  ('super cheap', 1),
#  ('so kind', 1),
#  ('very average', 1),
#  ('so delicious', 1),
#  ('really tasty', 1),
#  ('always hot', 1),
#  ('very good', 1),
#  ('very slow', 1),
#  ('very polite', 1),
#  ('very clean', 3),
#  ('really good', 3),
#  ('very friendly', 3),
#  ('very good', 2),
#  ('much better', 2),
#  ('too much', 2),
#  ('anywhere close', 2),
#  ('too sweet', 2),
#  ('so weak', 2),
#  ('exponentially better', 1),
#  ('very solid', 1),
#  ('super efficient', 1),
#  ('fully functional', 1),
#  ('even busy', 1),
#  ('very disappointed', 1),
#  ('once then more', 1),
#  ('always wrong always wrong always wrong ', 1),
#  ('all sticky all sticky ', 1),
#  ('totally disgusted', 1),
#  ('too long', 1),
#  ('pretty good', 1),
#  ('always minimum always minimum ', 1),
#  ('definitely better', 1),
#  ('more detailed', 1),
#  ('probably annoyed', 1),
#  ('fully satisfied', 1),
#  ('really nice', 1),
#  ('so frustrating', 1),
#  ('pretty obvious', 1),
#  ('as busy', 1),
#  ('so bitter', 1),
#  ('very sweet', 1),
#  ('really sweet', 1),
#  ('pretty rude', 1),
#  ('pretty accurate', 1),
#  ('extremely courteous', 1),
#  ('too way sweet', 1),
#  ('ie hot', 1),
#  ('extremely specific', 1),
#  ('somewhat tasty', 1),
#  ('surprisingly good', 1),
#  ('ahoy iced', 1),
#  ('less expensive', 1),
#  ('of old', 1),
#  ('super excited', 1),
#  ('very just disappointed', 1),
#  ('well worth', 1),
#  ('very quick', 1),
#  ('really bad', 1),
#  ('so hard', 1),
#  ('really damaging', 1),
#  ('very fresh', 1),
#  ('more important', 1),
#  ('extremely slow', 1),
#  ('so good', 1),
#  ('literally last', 1),
#  ('even bussy', 1),
#  ('kinda excited', 1),
#  ('neither hot', 1),
#  ('too way much', 1),
#  ('how much', 1),
#  ('very serious', 1),
#  ('even nice', 1),
#  ('very hard', 1),
#  ('very welcoming', 1),
#  ('extremely unprofessional', 1),
#  ('any ready', 1),
#  ('super fast', 1),
#  ('very nice', 1),
#  ('very disappointing', 1),
#  ('pretty complicated', 1),
#  ('actually better actually better actually better ', 1),
#  ('really excessive', 1),
#  ('easily accessible', 1),
#  ('always good always good always good ', 1),
#  ('very convenient', 1),
#  ('earlier where close', 1),
#  ('very strange', 1),
#  ('even good', 1),
#  ('so used', 1),
#  ('pretty awesome', 1),
#  ('very slow', 1),
#  ('so few', 1),
#  ('hard dark dry', 1),
#  ('extremely friendly', 1),
#  ('just enough', 1),
#  ('less heavy', 1),
#  ('nearly empty', 1),
#  ('about same', 1),
#  ('overly friendly', 1),
#  ('super welcoming', 1),
#  ('terribly wide', 1),
#  ('so special', 1),
#  ('where fresh', 1),
#  ('also dry', 1),
#  ('all clean', 1),
#  ('over cooked', 1),
#  ('too oily', 1),
#  ('very good', 5),
#  ('very tasty', 5),
#  ('really good', 4),
#  ('very attentive', 4),
#  ('so much', 3),
#  ('really busy', 3),
#  ('pretty good', 3),
#  ('very reasonable', 2),
#  ('too many', 2),
#  ('very generous', 2),
#  ('so hard', 2),
#  ('so rude', 2),
#  ('very helpful', 2),
#  ('very dense', 2),
#  ('so nice', 2),
#  ('very fresh', 2),
#  ('just same', 1),
#  ('even better', 1),
#  ('pretty still awesome', 1),
#  ('so impressed', 1),
#  ('so tender', 1),
#  ('much larger', 1),
#  ('how bright', 1),
#  ('well lit', 1),
#  ('indescribably rich', 1),
#  ('really fun', 1),
#  ('quite bare', 1),
#  ('very average', 1),
#  ('only nice', 1),
#  ('very exciting', 1),
#  ('very similar', 1),
#  ('very extensive', 1),
#  ('as just impressive', 1),
#  ('so tasty', 1),
#  ('completely disappointed', 1),
#  ('so even busy', 1),
#  ('very bad', 1),
#  ('super friendly', 1),
#  ('yet fragrant', 1),
#  ('so fun', 1),
#  ('too much', 1),
#  ('really encouraged', 1),
#  ('really disappointed', 1),
#  ('really salty', 1),
#  ('very busy', 1),
#  ('super trendy', 1),
#  ('aesthetically pleasing', 1),
#  ('well worth', 1),
#  ('that hungry', 1),
#  ('very hot', 1),
#  ('super ecstatic', 1),
#  ('how beautiful', 1),
#  ('really friendly', 1),
#  ('very acidic', 1),
#  ('most favorite', 1),
#  ('enough super big', 1),
#  ('so different', 1),
#  ('so delicious', 1),
#  ('well balanced', 1),
#  ('overly salty', 1),
#  ('really surprising', 1),
#  ('very delicious', 1),
#  ('absolutely amazing', 1),
#  ('as much', 1),
#  ('very fancy', 1),
#  ('so beautiful', 1),
#  ('very affordable', 1),
#  ('quite bland', 1),
#  ('mostly starchy', 1),
#  ('of small', 1),
#  ('very expensive', 1),
#  ('very dry', 1),
#  ('very corporate', 1),
#  ('very insensitive', 1),
#  ('honestly fair', 1),
#  ('pretty decent', 1),
#  ('culturally eclectic', 1),
#  ('super attentive', 1),
#  ('very likable', 1),
#  ('more enjoyable', 1),
#  ('incredibly tasty', 1),
#  ('very popular', 1),
#  ('totally brilliant', 1),
#  ('very modern', 1),
#  ('more straightforward', 1),
#  ('so disappointed', 1),
#  ('pretty positive', 1),
#  ('so many', 1),
#  ('mouthwateringly perfect', 1),
#  ('so refreshing', 1),
#  ('highly recommend', 1),
#  ('surprisingly crunchy', 1),
#  ('exceptionally friendly', 1),
#  ('so little', 1),
#  ('overall good', 1),
#  ('definitely worth', 1),
#  ('completely disorganized', 1),
#  ('pretty empty', 1),
#  ('very relaxing', 1),
#  ('even busy', 1),
#  ('quite slow', 1),
#  ('very smiley', 1),
#  ('extremely full', 1),
#  ('pretty disappointed', 1),
#  ('very nice', 1),
#  ('pretty romantic', 1),
#  ('too impressed', 1),
#  ('pretty disgusting', 1),
#  ('very unacceptable', 1),
#  ('very very good', 1),
#  ('very full', 1),
#  ('half full', 1),
#  ('maybe loud', 1),
#  ('so good', 1),
#  ('much better', 1),
#  ('just okay', 1),
#  ('way overcrowded', 1),
#  ('so full', 1),
#  ('pretty packed', 1),
#  ('quite new', 1),
#  ('extremely instead dry', 1),
#  ('very fun', 1),
#  ('most popular', 1),
#  ('very patient', 1),
#  ('really great', 1),
#  ('actually great actually great actually great actually great ', 1),
#  ('extremely friendly', 1),
#  ('particularly flavourful', 1),
#  ('completely underwhelming', 1),
#  ('enough moist', 1),
#  ('absolutely delicious', 1),
#  ('very happy', 1),
#  ('all nice', 1),
#  ('very difficult', 1),
#  ('rather small', 1),
#  ('more suited', 1),
#  ('so juicy', 1),
#  ('basically bibimbap', 1),
#  ('usually lively', 1),
#  ('pretty low', 1),
#  ('most simplistic', 1),
#  ('extremely difficult', 1),
#  ('super excited', 1),
#  ('really nice', 1),
#  ('how attractive', 1),
#  ('no different', 1),
#  ('also excellent also excellent ', 1),
#  ('almost sushi', 1),
#  ('too definitely much', 1),
#  ('super tender', 1),
#  ('very much', 1),
#  ('never now disappointed', 1),
#  ('slightly more', 1),
#  ('generally good generally good generally good ', 1),
#  ('unfortunatwly undercooked', 1),
#  ('choros(not bad', 1),
#  ('too way much', 1),
#  ('deathly sweet', 1),
#  ('very empty', 1),
#  ('of slow', 1),
#  ('so sweet', 1),
#  ('pretty plain', 1),
#  ('plain white', 1),
#  ('so bland', 1),
#  ('very salty', 1),
#  ('of strange', 1),
#  ('all friendly all friendly ', 1),
#  ('absolutely fantastic', 1),
#  ('very knowledgeable', 1),
#  ('very very special', 1),
#  ('well least', 1),
#  ('extremely mediocre', 1),
#  ('quite small', 1),
#  ('quite disappointing', 1),
#  ('very tiny', 1),
#  ('very thick', 1),
#  ('very sweet', 1),
#  ('just disappointed', 1),
#  ('very curious', 1),
#  ('pretty good', 4),
#  ('really nice', 4),
#  ('really good', 3),
#  ('too bad', 3),
#  ('too crowded', 3),
#  ('nearly empty', 3),
#  ('so good', 2),
#  ('very small', 2),
#  ('too much', 2),
#  ('too loud', 2),
#  ('too many', 2),
#  ('very good', 2),
#  ('incredibly good', 2),
#  ('very crowded', 2),
#  ('very nice', 2),
#  ('well worth', 2),
#  ('incredibly friendly', 1),
#  ('anywhere worth', 1),
#  ('just flat', 1),
#  ('too packed', 1),
#  ('just glad', 1),
#  ('how different', 1),
#  ('pretty cool', 1),
#  ('pretty small', 1),
#  ('too expensive', 1),
#  ('super cool', 1),
#  ('extremely inebriated', 1),
#  ('so pissed', 1),
#  ('most shit', 1),
#  ('very relaxed', 1),
#  ('pretty spacious', 1),
#  ('however many', 1),
#  ('practically dead', 1),
#  ('impossibly thin', 1),
#  ('too way spicy', 1),
#  ('too way tiny', 1),
#  ('so hot', 1),
#  ('pretty upscale', 1),
#  ('under experienced', 1),
#  ('more approachable', 1),
#  ('very strong', 1),
#  ('very little', 1),
#  ('over crowded', 1),
#  ('pretty dark', 1),
#  ('just okay', 1),
#  ('too pricey', 1),
#  ('very spacious', 1),
#  ('very friendly', 1),
#  ('relatively high', 1),
#  ('really tasty', 1),
#  ('all dark', 1),
#  ('seemingly sophisticated', 1),
#  ('pretty attractive', 1),
#  ('extra pissed', 1),
#  ('just sad', 1),
#  ('as many', 1),
#  ('super rude', 1),
#  ('actually lucky actually lucky actually lucky actually lucky ', 1),
#  ('enough lucky', 1),
#  ('how cozy', 1),
#  ('pretty steep', 1),
#  ('very sexy', 1),
#  ('pretty similar', 1),
#  ('pretty friendly', 1),
#  ('very dark', 1),
#  ('of nice', 1),
#  ('enough loud', 1),
#  ('fairly empty', 1),
#  ('pretty standard', 1),
#  ('rather loud', 1),
#  ('more delicious', 1),
#  ('there damn too dark', 1),
#  ('too small', 1),
#  ('enough good', 1),
#  ('as honest', 1),
#  ('more busy', 1),
#  ('extremely fun', 1),
#  ('quite dark', 1),
#  ('really difficult', 1),
#  ('very fun', 1),
#  ('pretty buss', 1),
#  ('definitely decorative', 1),
#  ('pretty tasty', 1),
#  ('even more', 1),
#  ('though pretentious', 1),
#  ('so warm', 1),
#  ('really bright', 1),
#  ('very dim', 1),
#  ('at least', 1),
#  ('enough friendly', 1),
#  ('so small', 1),
#  ('how nice', 1),
#  ('kinda cool', 1),
#  ('much better', 1),
#  ('as sophisticated', 1),
#  ('too young', 1),
#  ('too drunk', 1),
#  ('more dynamic', 1),
#  ('really casual', 1),
#  ('really ridiculous', 1),
#  ('really uncomfortable', 1),
#  ('more like', 1),
#  ('enough old', 1),
#  ('somewhat short', 1),
#  ('practically empty', 1),
#  ('really drunk', 1),
#  ('so much', 1),
#  ('most great', 1),
#  ('very famous', 1),
#  ('how small', 1),
#  ('much friendlier', 1),
#  ('only few', 1),
#  ('too partied', 1),
#  ('very key', 1),
#  ('very quaint', 1),
#  ('damn good', 1),
#  ('very surprising', 1),
#  ('little more', 1),
#  ('almost empty', 1),
#  ('very danceable', 1),
#  ('so danceable', 1),
#  ('much more', 1),
#  ('so grand', 1),
#  ('how rude', 1),
#  ('completely disgusted', 1),
#  ('completely bad', 1),
#  ('quite small', 1),
#  ('too hard', 1),
#  ('even worse', 3),
#  ('very thorough', 2),
#  ('very friendly', 2),
#  ('very bad', 2),
#  ('so many', 2),
#  ('how much', 2),
#  ('much more', 2),
#  ('pretty clean', 2),
#  ('so much', 2),
#  ('so disappointed', 2),
#  ('how good', 2),
#  ('very poor', 1),
#  ('pretty helpful', 1),
#  ('so bad', 1),
#  ('really horrible', 1),
#  ('more expensive', 1),
#  ('very pleased', 1),
#  ('that worried', 1),
#  ('pretty good', 1),
#  ('sparkly all clean', 1),
#  ('how dirty', 1),
#  ('only good', 1),
#  ('sh*tty est', 1),
#  ('just terrible', 1),
#  ('well worth', 1),
#  ('very careful', 1),
#  ('really nice', 1),
#  ('glacially slow', 1),
#  ('even when busy', 1),
#  ('so happy', 1),
#  ('completely detailed', 1),
#  ('most horrible', 1),
#  ('really pleasant', 1),
#  ('so used', 1),
#  ('meticulously clean', 1),
#  ('very comfortable', 1),
#  ('very nice', 1),
#  ('as clean', 1),
#  ('very few', 1),
#  ('definitely best', 1),
#  ('terribly wrong', 1),
#  ('even comparable', 1),
#  ('pretty sloppy', 1),
#  ('just dusty', 1),
#  ('too many', 1),
#  ('pretty substandard', 1),
#  ('enough expensive', 1),
#  ('very least', 1),
#  ('very narrow', 1),
#  ('pretty thorough', 1),
#  ('always double', 1),
#  ('very kind', 1),
#  ('how busy', 1),
#  ('pretty satisfied', 1),
#  ('how long', 1),
#  ('quite frustrated', 1),
#  ('much higher', 1),
#  ('quite disappointed', 1),
#  ('so nice', 1),
#  ('how many', 1),
#  ('pretty shiny', 1),
#  ('very dirty', 1),
#  ('still wet still wet still wet still wet ', 1),
#  ('really mad', 1),
#  ('fast clean', 1),
#  ('most basic', 1),
#  ('very pricey', 1),
#  ('really desperate', 1),
#  ('really good', 1),
#  ('obviously distressing', 1),
#  ('always immaculate always immaculate ', 1),
#  ('very helpful', 1),
#  ('extremely friendly', 1),
#  ('still dirty still dirty still dirty still dirty still dirty ', 1),
#  ('any better', 1),
#  ('much better', 1),
#  ('that dirty', 1),
#  ('always impressed always impressed ', 1),
#  ('how quick', 1),
#  ('how nice', 1),
#  ('overly aggressive', 1),
#  ('very clean', 1),
#  ('very crappy', 1),
#  ('super dirty', 1),
#  ('as great', 1),
#  ('very happy', 1),
#  ('anywhere else!,terrible', 1),
#  ('only concerned', 1),
#  ('more noticeable', 1),
#  ('extremely valuable', 1),
#  ('obviously valuable', 1),
#  ('just ok', 1),
#  ('really bad', 1),
#  ('just wet', 1),
#  ('still dirty', 1),
#  ('as just dirty', 1),
#  ('more interested', 1),
#  ('how disappointed', 1),
#  ('very personable', 1),
#  ('unfortunately knowledgable', 1),
#  ('as smooth', 1),
#  ('clearly visible', 1),
#  ('otherwise physical', 1),
#  ('too bad', 1),
#  ('very relaxing', 8),
#  ('very professional', 4),
#  ('very good', 4),
#  ('very friendly', 4),
#  ('very pleasant', 3),
#  ('absolutely amazing', 3),
#  ('so great', 2),
#  ('well worth', 2),
#  ('so thankful', 2),
#  ('too many', 2),
#  ('so happy', 2),
#  ('so relaxing', 2),
#  ('so sweet', 2),
#  ('really friendly', 2),
#  ('very attentive', 2),
#  ('most relaxing', 2),
#  ('super friendly', 2),
#  ('so relaxed', 2),
#  ('most amazing', 2),
#  ('so warm', 2),
#  ('really nice', 2),
#  ('really great', 2),
#  ('really good', 2),
#  ('very reasonable', 2),
#  ('so many', 2),
#  ('also wonderful also wonderful ', 1),
#  ('really hard', 1),
#  ('extremely clean', 1),
#  ('extremely accomodating', 1),
#  ('super nice', 1),
#  ('very peaceful', 1),
#  ('completely relaxed', 1),
#  ('incredibly disappointed', 1),
#  ('very serene', 1),
#  ('extremely competent', 1),
#  ('always able always able ', 1),
#  ('about half', 1),
#  ('least pricey', 1),
#  ('super relaxing', 1),
#  ('really weak', 1),
#  ('more like', 1),
#  ('super easy', 1),
#  ('too chatty', 1),
#  ('highly recommend', 1),
#  ('very gracious', 1),
#  ('most expert', 1),
#  ('really long', 1),
#  ('personally friendly', 1),
#  ('extremely dry', 1),
#  ('absolutely glowing', 1),
#  ('so knowledgeable', 1),
#  ('very enjoyable', 1),
#  ('very concerned', 1),
#  ('as good', 1),
#  ('highly impressed', 1),
#  ('even easier', 1),
#  ('so enjoyable', 1),
#  ('quite amazing', 1),
#  ('largely organic', 1),
#  ('very different', 1),
#  ('more positive', 1),
#  ('incredibly personable', 1),
#  ('less clinical', 1),
#  ('extremely lovely', 1),
#  ('more reasonable', 1),
#  ('more expensive', 1),
#  ('still sure', 1),
#  ('just okay', 1),
#  ('so atmosphere- relaxing', 1),
#  ('usually lavender', 1),
#  ('very thorough', 1),
#  ('so hot', 1),
#  ('all professional', 1),
#  ('very hygienic', 1),
#  ('really fast', 1),
#  ('incredibly strong', 1),
#  ('overall really just disappointing', 1),
#  ('somewhat nitpicky', 1),
#  ('just terrible', 1),
#  ('more stressed', 1),
#  ('how much', 1),
#  ('very awkward', 1),
#  ('very annoying', 1),
#  ('too high', 1),
#  ('yet more energized', 1),
#  ('very misled', 1),
#  ('so positive', 1),
#  ('extremely kind', 1),
#  ('more relaxing', 1),
#  ('super excited', 1),
#  ('always courteous', 1),
#  ('so welcoming', 1),
#  ('really fantastic', 1),
#  ('very helpful', 1),
#  ('pretty awesome', 1),
#  ('mostly big', 1),
#  ('very low', 1),
#  ('very easy', 1),
#  ('somewhat picky', 1),
#  ('consistently great', 1),
#  ('most beautiful', 1),
#  ('all organic all organic all organic all organic ', 1),
#  ('ever first', 1),
#  ('extremely friendly', 1),
#  ('totally hilarious', 1),
#  ('very technically talented', 1),
#  ('very lucky', 1),
#  ('very light', 1),
#  ('too long', 1),
#  ('so comfortable', 1),
#  ('pretty relaxing', 1),
#  ('much better', 1),
#  ('so comforting', 1),
#  ('very nice', 1),
#  ('really mixed', 1),
#  ('actually lovely', 1),
#  ('definitely conducive', 1),
#  ('super funny', 1),
#  ('so smart', 1),
#  ('extremely relaxing', 1),
#  ('thoroughly displeased', 1),
#  ('very happy', 1),
#  ('super relaxed', 1),
#  ('technically great', 1),
#  ('more clinical', 1),
#  ('extremely professional', 1),
#  ('super knowledgeable', 1),
#  ('also certified ', 1),
#  ('currently pregnant currently pregnant currently pregnant ', 1),
#  ...]

# %%
DF = {}
for i, phrase_tuple in enumerate(common_phrases):
    phrase: str = phrase_tuple[0]
    try:
        DF[phrase].add(i)
    except:
        DF[phrase] = {i}

# %%
# count across the entire document
for i in DF:
    DF[i] = len(DF[i])
DF
# Out:
# {'very good': 135,
#  'pretty good': 121,
#  'really good': 129,
#  'very friendly': 124,
#  'very busy': 51,
#  'very pleased': 39,
#  'at least': 53,
#  'too much': 101,
#  'much better': 99,
#  'too busy': 51,
#  'very spacious': 14,
#  'very large': 34,
#  'very attentive': 56,
#  'super friendly': 81,
#  'so good': 111,
#  'always good always good always good ': 15,
#  'just typical': 1,
#  'just average': 12,
#  'also fantastic also fantastic also fantastic also fantastic ': 1,
#  'how good': 34,
#  'how delicious': 10,
#  'very prompt': 5,
#  'even fewer': 1,
#  'real good': 6,
#  'pretty decent': 43,
#  'no better': 8,
#  'most recent': 28,
#  'pretty average': 7,
#  'way friendlier': 1,
#  'exceptionally good': 4,
#  'extremely greasy': 3,
#  'very empty': 2,
#  'enough large': 9,
#  'barely hot': 2,
#  'extremely attentive': 8,
#  'too many': 53,
#  'super busy': 23,
#  'really nice': 83,
#  'so excited': 31,
#  'too low': 2,
#  'more interested': 9,
#  'very nice': 129,
#  'how busy': 27,
#  'just wonderful': 5,
#  'pretty awesome': 16,
#  'ridiculously good': 4,
#  'pretty surprisingly darn': 1,
#  'just sad': 5,
#  'all exceptional all exceptional ': 1,
#  'very reasonable': 60,
#  'very marginal': 1,
#  'pretty empty': 9,
#  'always friendly always friendly ': 16,
#  'decent(not worth decent(not worth decent(not worth decent(not worth ': 1,
#  'very disappointing': 28,
#  'all lumpy': 1,
#  'very perticular': 1,
#  'so bizarre': 1,
#  'very expensive': 16,
#  'very loud': 14,
#  'just ok': 38,
#  'definitely worth definitely worth ': 9,
#  'really small': 6,
#  'very least': 11,
#  'less complacent': 1,
#  'pleasantly surprised': 62,
#  'just ok just ok just ok ': 3,
#  'very overpriced': 4,
#  'very average': 15,
#  'mostly attentive mostly attentive mostly attentive mostly attentive ': 1,
#  'really sure': 8,
#  'so great': 42,
#  'on great': 1,
#  'very comfortable': 23,
#  'at best': 27,
#  'really plentiful': 1,
#  'very disappointing!,this': 1,
#  'that good': 35,
#  'how wonderful': 8,
#  'pretty hard': 6,
#  'little odd': 4,
#  'maybe few': 1,
#  'very crunchy': 4,
#  'often good': 1,
#  'very rushed': 6,
#  'super loud': 3,
#  'so loud': 9,
#  'fairly quick': 9,
#  'quite good': 42,
#  'very saturated': 1,
#  'all worth': 9,
#  'very picky': 11,
#  'how accurate': 1,
#  'very oily': 3,
#  'fairly speedy': 2,
#  'very happy': 50,
#  'very tasty': 71,
#  'very kid': 1,
#  'fairly poor': 1,
#  'really busy': 25,
#  'only friendly': 1,
#  'always huge always huge ': 1,
#  'so big': 13,
#  'so many': 107,
#  'most specific': 1,
#  'certainly healthy': 1,
#  'great dry': 1,
#  'more concerned': 8,
#  'as many': 19,
#  'more accurate': 2,
#  'always prompt always prompt ': 3,
#  'very dark': 8,
#  'how dark': 1,
#  'consistently delicious': 7,
#  'better good': 1,
#  'so addictive': 3,
#  'very fresh': 41,
#  'so fresh': 34,
#  'extremely fresh': 5,
#  'very small': 54,
#  'pretty busy': 21,
#  'quite nice': 10,
#  'quite small': 16,
#  'that big': 14,
#  'that great': 35,
#  'quite busy': 13,
#  'definitely worth': 36,
#  'how small': 6,
#  'too loud': 15,
#  'well prepared': 16,
#  'sometimes cold sometimes cold sometimes cold sometimes cold sometimes cold ': 1,
#  'sometimes hot': 1,
#  'very again inconsistent': 1,
#  'generally sub generally sub generally sub generally sub ': 1,
#  'enough lucky': 20,
#  'quite full': 3,
#  'too bit much': 1,
#  'quite fast': 2,
#  'slightly cheaper': 1,
#  'really fresh': 5,
#  'everywhere albeit same': 1,
#  'that bad': 24,
#  'really bad': 26,
#  'really friendly': 33,
#  'very enjoyable': 15,
#  'extremely disappointed': 16,
#  'very bad': 23,
#  'always quick always quick ': 5,
#  'really impressed': 18,
#  'just regular': 1,
#  'quite modern': 2,
#  'always courteous always courteous ': 4,
#  'loosely packed': 1,
#  'too chewy': 3,
#  'still slow': 1,
#  'more skilled': 1,
#  'more additional': 1,
#  'as just satisfying': 1,
#  'always busy': 2,
#  'how hungry': 5,
#  'most shameful': 1,
#  'strictly japanese': 1,
#  'somewhat modern': 1,
#  'really tough': 4,
#  'how much': 64,
#  'how many': 47,
#  'partly due': 1,
#  'just shocked': 1,
#  'more expensive': 43,
#  'very big': 22,
#  'very limited': 24,
#  'very convenient': 19,
#  'pretty small': 19,
#  'pretty common': 4,
#  'pretty thin': 5,
#  'very appealing': 4,
#  'even busy': 11,
#  'quite empty': 3,
#  'quite large': 14,
#  'neatly furnished': 1,
#  'slightly upscale': 1,
#  'much thinner': 2,
#  'only available': 5,
#  'too all bad': 1,
#  'quite impressive': 6,
#  'so worth': 18,
#  'most consistent': 2,
#  'pretty extensive': 4,
#  'definitely different definitely different ': 1,
#  'pretty still good': 2,
#  'also delicious also delicious ': 9,
#  'really loud': 1,
#  'very little': 43,
#  'also full also full ': 1,
#  'really mushy': 1,
#  'quite reasonable': 6,
#  'actually good actually good ': 2,
#  'more personal': 2,
#  'usually ready usually ready ': 1,
#  'very different': 16,
#  'all fresh all fresh ': 1,
#  'as extensive': 2,
#  'really grouchy': 1,
#  'just great': 11,
#  'too salty': 39,
#  'so moist': 4,
#  'very irritating': 1,
#  'too small': 22,
#  'very high': 16,
#  'quite economical': 1,
#  'very sullen': 1,
#  'too late': 16,
#  'enough big': 13,
#  'slightly uncomfortable': 3,
#  'how insulting': 2,
#  'very uncomfortable': 7,
#  'probably better probably better ': 2,
#  'of mean': 1,
#  'extremely yet efficient': 1,
#  'all surprised': 1,
#  'so tasty': 18,
#  'disappointed!,the good': 1,
#  'very low': 14,
#  'as impressive': 3,
#  'extremely slimy': 1,
#  'certainly good': 1,
#  'more solid': 4,
#  'that much': 8,
#  'seemingly unhappy': 1,
#  'surprisingly busy': 1,
#  'really yummy': 8,
#  'always fresh': 13,
#  'there decent': 1,
#  'much bigger': 8,
#  'so hard': 21,
#  'so already full': 1,
#  'kill!,pleasantly surprised': 1,
#  'of nice': 2,
#  'as good': 70,
#  'pretty tasty': 25,
#  'consistently good': 24,
#  'always friendly': 11,
#  'very simple': 19,
#  'extremely nice': 23,
#  'very few': 27,
#  'pretty sure': 29,
#  'very surprised': 9,
#  'as much': 39,
#  'very spongy': 1,
#  'too cheap': 3,
#  'as poor': 1,
#  'totally disappointed': 3,
#  'really inconsistent': 1,
#  'even better': 49,
#  'around worst': 1,
#  'pretty old': 3,
#  'late cold': 1,
#  'just right': 33,
#  'more fresh': 9,
#  'especially great': 4,
#  'so nice': 56,
#  'too long': 26,
#  'where annoyed': 1,
#  'also great also great ': 11,
#  'even apologetic': 3,
#  'very consistent': 8,
#  'very orangey': 1,
#  'very clean': 75,
#  'very best': 12,
#  'of annoying': 3,
#  'very delicious': 43,
#  'all empty all empty all empty all empty ': 1,
#  'consistently decent': 2,
#  'even close': 11,
#  'always dirty always dirty ': 3,
#  'too exciting': 2,
#  'enough good': 37,
#  'fatty hard': 1,
#  'too bad': 79,
#  'almost offensive': 1,
#  'damn good': 13,
#  'slightly spicy': 3,
#  'never equal': 1,
#  'very hefty': 2,
#  'very generous': 29,
#  'very hot': 19,
#  'temp(not frozen': 1,
#  'as just good': 20,
#  'fairly fresh': 1,
#  'much overall better': 1,
#  'as just easy': 1,
#  'very complex': 1,
#  'so salty': 7,
#  'usually overwhelming': 1,
#  'too sweet': 34,
#  'really wrong': 2,
#  'of soggy': 2,
#  'so glad': 60,
#  'so polite': 5,
#  'so just much': 2,
#  'severly understaffed': 1,
#  'still good still good still good still good still good ': 1,
#  'very very poor': 2,
#  'most disappointing': 9,
#  'much more': 45,
#  'extremely brown': 1,
#  'so dirty': 2,
#  'so blase': 1,
#  'all fine all fine ': 1,
#  'always great always great ': 13,
#  'super cheap': 9,
#  'so kind': 17,
#  'so delicious': 39,
#  'really tasty': 21,
#  'always hot': 4,
#  'very slow': 22,
#  'very polite': 22,
#  'anywhere close': 4,
#  'so weak': 2,
#  'exponentially better': 1,
#  'very solid': 5,
#  'super efficient': 1,
#  'fully functional': 2,
#  'very disappointed': 48,
#  'once then more': 1,
#  'always wrong always wrong always wrong ': 1,
#  'all sticky all sticky ': 1,
#  'totally disgusted': 3,
#  'always minimum always minimum ': 1,
#  'definitely better': 3,
#  'more detailed': 4,
#  'probably annoyed': 1,
#  'fully satisfied': 2,
#  'so frustrating': 2,
#  'pretty obvious': 1,
#  'as busy': 4,
#  'so bitter': 1,
#  'very sweet': 36,
#  'really sweet': 6,
#  'pretty rude': 4,
#  'pretty accurate': 4,
#  'extremely courteous': 4,
#  'too way sweet': 3,
#  'ie hot': 1,
#  'extremely specific': 1,
#  'somewhat tasty': 1,
#  'surprisingly good': 11,
#  'ahoy iced': 1,
#  'less expensive': 18,
#  'of old': 2,
#  'super excited': 9,
#  'very just disappointed': 1,
#  'well worth': 55,
#  'very quick': 23,
#  'really damaging': 1,
#  'more important': 8,
#  'extremely slow': 11,
#  'literally last': 1,
#  'even bussy': 1,
#  'kinda excited': 1,
#  'neither hot': 1,
#  'too way much': 24,
#  'very serious': 2,
#  'even nice': 1,
#  'very hard': 13,
#  'very welcoming': 23,
#  'extremely unprofessional': 6,
#  'any ready': 1,
#  'super fast': 18,
#  'pretty complicated': 1,
#  'actually better actually better actually better ': 1,
#  'really excessive': 1,
#  'easily accessible': 4,
#  'earlier where close': 1,
#  'very strange': 6,
#  'even good': 2,
#  'so used': 3,
#  'so few': 2,
#  'hard dark dry': 1,
#  'extremely friendly': 40,
#  'just enough': 11,
#  'less heavy': 2,
#  'nearly empty': 3,
#  'about same': 4,
#  'overly friendly': 3,
#  'super welcoming': 1,
#  'terribly wide': 1,
#  'so special': 4,
#  'where fresh': 1,
#  'also dry': 1,
#  'all clean': 2,
#  'over cooked': 28,
#  'too oily': 11,
#  'so much': 94,
#  'so rude': 15,
#  'very helpful': 65,
#  'very dense': 3,
#  'just same': 1,
#  'pretty still awesome': 1,
#  'so impressed': 20,
#  'so tender': 14,
#  'much larger': 11,
#  'how bright': 1,
#  'well lit': 4,
#  'indescribably rich': 1,
#  'really fun': 8,
#  'quite bare': 1,
#  'only nice': 1,
#  'very exciting': 3,
#  'very similar': 18,
#  'very extensive': 6,
#  'as just impressive': 1,
#  'completely disappointed': 4,
#  'so even busy': 1,
#  'yet fragrant': 1,
#  'so fun': 6,
#  'really encouraged': 1,
#  'really disappointed': 20,
#  'really salty': 2,
#  'super trendy': 2,
#  'aesthetically pleasing': 5,
#  'that hungry': 5,
#  'super ecstatic': 1,
#  'how beautiful': 4,
#  'very acidic': 1,
#  'most favorite': 5,
#  'enough super big': 1,
#  'so different': 4,
#  'well balanced': 11,
#  'overly salty': 11,
#  'really surprising': 1,
#  'absolutely amazing': 29,
#  'very fancy': 5,
#  'so beautiful': 6,
#  'very affordable': 16,
#  'quite bland': 5,
#  'mostly starchy': 1,
#  'of small': 7,
#  'very dry': 16,
#  'very corporate': 1,
#  'very insensitive': 2,
#  'honestly fair': 1,
#  'culturally eclectic': 1,
#  'super attentive': 7,
#  'very likable': 2,
#  'more enjoyable': 7,
#  'incredibly tasty': 2,
#  'very popular': 13,
#  'totally brilliant': 1,
#  'very modern': 14,
#  'more straightforward': 1,
#  'so disappointed': 25,
#  'pretty positive': 4,
#  'mouthwateringly perfect': 1,
#  'so refreshing': 8,
#  'highly recommend': 11,
#  'surprisingly crunchy': 1,
#  'exceptionally friendly': 7,
#  'so little': 9,
#  'overall good': 4,
#  'completely disorganized': 1,
#  'very relaxing': 14,
#  'quite slow': 8,
#  'very smiley': 1,
#  'extremely full': 1,
#  'pretty disappointed': 10,
#  'pretty romantic': 1,
#  'too impressed': 5,
#  'pretty disgusting': 4,
#  'very unacceptable': 1,
#  'very very good': 11,
#  'very full': 10,
#  'half full': 6,
#  'maybe loud': 1,
#  'just okay': 23,
#  'way overcrowded': 1,
#  'so full': 13,
#  'pretty packed': 4,
#  'quite new': 2,
#  'extremely instead dry': 1,
#  'very fun': 9,
#  'most popular': 11,
#  'very patient': 17,
#  'really great': 50,
#  'actually great actually great actually great actually great ': 1,
#  'particularly flavourful': 1,
#  'completely underwhelming': 2,
#  'enough moist': 1,
#  'absolutely delicious': 35,
#  'all nice': 3,
#  'very difficult': 11,
#  'rather small': 6,
#  'more suited': 2,
#  'so juicy': 7,
#  'basically bibimbap': 1,
#  'usually lively': 1,
#  'pretty low': 7,
#  'most simplistic': 1,
#  'extremely difficult': 5,
#  'how attractive': 1,
#  'no different': 7,
#  'also excellent also excellent ': 7,
#  'almost sushi': 1,
#  'too definitely much': 1,
#  'super tender': 5,
#  'very much': 3,
#  'never now disappointed': 1,
#  'slightly more': 5,
#  'generally good generally good generally good ': 1,
#  'unfortunatwly undercooked': 1,
#  'choros(not bad': 1,
#  'deathly sweet': 1,
#  'of slow': 3,
#  'so sweet': 25,
#  'pretty plain': 3,
#  'plain white': 3,
#  'so bland': 5,
#  'very salty': 16,
#  'of strange': 2,
#  'all friendly all friendly ': 1,
#  'absolutely fantastic': 3,
#  'very knowledgeable': 27,
#  'very very special': 1,
#  'well least': 1,
#  'extremely mediocre': 1,
#  'quite disappointing': 9,
#  'very tiny': 6,
#  'very thick': 15,
#  'just disappointed': 4,
#  'very curious': 1,
#  'too crowded': 17,
#  'incredibly good': 2,
#  'very crowded': 13,
#  'incredibly friendly': 14,
#  'anywhere worth': 1,
#  'just flat': 1,
#  'too packed': 2,
#  'just glad': 5,
#  'how different': 2,
#  'pretty cool': 24,
#  'too expensive': 15,
#  'super cool': 12,
#  'extremely inebriated': 1,
#  'so pissed': 2,
#  'most shit': 1,
#  'very relaxed': 7,
#  'pretty spacious': 5,
#  'however many': 2,
#  'practically dead': 1,
#  'impossibly thin': 1,
#  'too way spicy': 2,
#  'too way tiny': 1,
#  'so hot': 9,
#  'pretty upscale': 1,
#  'under experienced': 1,
#  'more approachable': 1,
#  'very strong': 8,
#  'over crowded': 2,
#  'pretty dark': 2,
#  'too pricey': 11,
#  'relatively high': 4,
#  'all dark': 1,
#  'seemingly sophisticated': 1,
#  'pretty attractive': 2,
#  'extra pissed': 1,
#  'super rude': 6,
#  'actually lucky actually lucky actually lucky actually lucky ': 1,
#  'how cozy': 1,
#  'pretty steep': 4,
#  'very sexy': 2,
#  'pretty similar': 4,
#  'pretty friendly': 5,
#  'enough loud': 4,
#  'fairly empty': 2,
#  'pretty standard': 23,
#  'rather loud': 1,
#  'more delicious': 3,
#  'there damn too dark': 1,
#  'as honest': 2,
#  'more busy': 1,
#  'extremely fun': 1,
#  'quite dark': 2,
#  'really difficult': 5,
#  'pretty buss': 1,
#  'definitely decorative': 1,
#  'even more': 9,
#  'though pretentious': 1,
#  'so warm': 4,
#  'really bright': 4,
#  'very dim': 2,
#  'enough friendly': 10,
#  'so small': 13,
#  'how nice': 10,
#  'kinda cool': 3,
#  'as sophisticated': 1,
#  'too young': 2,
#  'too drunk': 1,
#  'more dynamic': 1,
#  'really casual': 1,
#  'really ridiculous': 2,
#  'really uncomfortable': 2,
#  'more like': 3,
#  'enough old': 3,
#  'somewhat short': 1,
#  'practically empty': 4,
#  'really drunk': 1,
#  'most great': 1,
#  'very famous': 1,
#  'much friendlier': 2,
#  'only few': 29,
#  'too partied': 1,
#  'very key': 1,
#  'very quaint': 2,
#  'very surprising': 1,
#  'little more': 8,
#  'almost empty': 9,
#  'very danceable': 1,
#  'so danceable': 1,
#  'so grand': 1,
#  'how rude': 7,
#  'completely disgusted': 1,
#  'completely bad': 1,
#  'too hard': 12,
#  'even worse': 17,
#  'very thorough': 15,
#  'pretty clean': 9,
#  'very poor': 19,
#  'pretty helpful': 1,
#  'so bad': 57,
#  'really horrible': 2,
#  'that worried': 1,
#  'sparkly all clean': 1,
#  'how dirty': 5,
#  'only good': 2,
#  'sh*tty est': 1,
#  'just terrible': 4,
#  'very careful': 4,
#  'glacially slow': 2,
#  'even when busy': 1,
#  'so happy': 44,
#  'completely detailed': 1,
#  'most horrible': 3,
#  'really pleasant': 3,
#  'meticulously clean': 1,
#  'as clean': 6,
#  'definitely best': 3,
#  'terribly wrong': 2,
#  'even comparable': 1,
#  'pretty sloppy': 1,
#  'just dusty': 1,
#  'pretty substandard': 1,
#  'enough expensive': 1,
#  'very narrow': 4,
#  'pretty thorough': 1,
#  'always double': 2,
#  'very kind': 20,
#  'pretty satisfied': 2,
#  'how long': 6,
#  'quite frustrated': 1,
#  'much higher': 10,
#  'quite disappointed': 9,
#  'pretty shiny': 1,
#  'very dirty': 4,
#  'still wet still wet still wet still wet ': 2,
#  'really mad': 4,
#  'fast clean': 1,
#  'most basic': 3,
#  'very pricey': 3,
#  'really desperate': 1,
#  'obviously distressing': 1,
#  'always immaculate always immaculate ': 1,
#  'still dirty still dirty still dirty still dirty still dirty ': 2,
#  'any better': 7,
#  'that dirty': 1,
#  'always impressed always impressed ': 2,
#  'how quick': 4,
#  'overly aggressive': 2,
#  'very crappy': 1,
#  'super dirty': 4,
#  'as great': 10,
#  'anywhere else!,terrible': 1,
#  'only concerned': 2,
#  'more noticeable': 1,
#  'extremely valuable': 1,
#  'obviously valuable': 1,
#  'just wet': 1,
#  'still dirty': 1,
#  'as just dirty': 1,
#  'how disappointed': 2,
#  'very personable': 12,
#  'unfortunately knowledgable': 1,
#  'as smooth': 3,
#  'clearly visible': 2,
#  'otherwise physical': 1,
#  'very professional': 32,
#  'very pleasant': 32,
#  'so thankful': 14,
#  'so relaxing': 4,
#  'most relaxing': 1,
#  'so relaxed': 4,
#  'most amazing': 17,
#  'also wonderful also wonderful ': 4,
#  'really hard': 7,
#  'extremely clean': 8,
#  'extremely accomodating': 1,
#  'super nice': 52,
#  'very peaceful': 3,
#  'completely relaxed': 4,
#  'incredibly disappointed': 2,
#  'very serene': 1,
#  'extremely competent': 1,
#  'always able always able ': 1,
#  'about half': 3,
#  'least pricey': 1,
#  'super relaxing': 2,
#  'really weak': 1,
#  'super easy': 9,
#  'too chatty': 2,
#  'very gracious': 3,
#  'most expert': 1,
#  'really long': 7,
#  'personally friendly': 1,
#  'extremely dry': 8,
#  'absolutely glowing': 1,
#  'so knowledgeable': 6,
#  'very concerned': 2,
#  'highly impressed': 3,
#  'even easier': 1,
#  'so enjoyable': 3,
#  'quite amazing': 2,
#  'largely organic': 1,
#  'more positive': 4,
#  'incredibly personable': 2,
#  'less clinical': 1,
#  'extremely lovely': 1,
#  'more reasonable': 9,
#  'still sure': 1,
#  'so atmosphere- relaxing': 1,
#  'usually lavender': 1,
#  'all professional': 1,
#  'very hygienic': 2,
#  'really fast': 3,
#  'incredibly strong': 1,
#  'overall really just disappointing': 1,
#  'somewhat nitpicky': 1,
#  'more stressed': 1,
#  'very awkward': 4,
#  'very annoying': 11,
#  'too high': 19,
#  'yet more energized': 1,
#  'very misled': 1,
#  'so positive': 2,
#  'extremely kind': 4,
#  'more relaxing': 2,
#  'always courteous': 1,
#  'so welcoming': 10,
#  'really fantastic': 1,
#  'mostly big': 1,
#  'very easy': 18,
#  'somewhat picky': 1,
#  'consistently great': 4,
#  'most beautiful': 6,
#  'all organic all organic all organic all organic ': 1,
#  'ever first': 2,
#  'totally hilarious': 1,
#  'very technically talented': 1,
#  'very lucky': 4,
#  'very light': 8,
#  'so comfortable': 8,
#  'pretty relaxing': 1,
#  'so comforting': 7,
#  'really mixed': 1,
#  'actually lovely': 1,
#  'definitely conducive': 1,
#  'super funny': 3,
#  'so smart': 2,
#  'extremely relaxing': 2,
#  'thoroughly displeased': 1,
#  'super relaxed': 3,
#  'technically great': 1,
#  'more clinical': 1,
#  'extremely professional': 8,
#  'super knowledgeable': 5,
#  'also certified ': 1,
#  'currently pregnant currently pregnant currently pregnant ': 1,
#  'very rude': 33,
#  'completely new': 4,
#  'how important': 4,
#  'as simple': 4,
#  'totally comfortable': 3,
#  'really worth': 9,
#  'very chilly': 1,
#  'pretty big': 28,
#  'absolutely best': 5,
#  'more relaxed': 3,
#  'most experienced': 2,
#  'most generous': 1,
#  'totally worth': 28,
#  'super clean': 23,
#  'extremely tasty': 3,
#  'pretty impressed': 7,
#  'extremely busy': 12,
#  'pretty gross': 4,
#  'gruellingly slow': 1,
#  'extra busy': 1,
#  'enough adequate': 1,
#  'less familiar': 2,
#  'just standard': 1,
#  'more popular': 9,
#  'likely more': 1,
#  'considerably hotter': 1,
#  'most important': 21,
#  'how popular': 1,
#  'deathly spicy': 1,
#  'painfully long': 2,
#  'absolutely massive': 2,
#  'so huge': 6,
#  'so convinced': 1,
#  'pretty true': 1,
#  'pretty full': 15,
#  'never again!!!!,used': 1,
#  'always busy always busy always busy ': 7,
#  'pretty annoying': 3,
#  'really disorganized': 1,
#  'pretty clear': 3,
#  'extremely great': 1,
#  'just jealous': 1,
#  'just curious': 1,
#  'particularly small': 1,
#  'completely different': 14,
#  'mildly gross': 1,
#  'how just much': 1,
#  'mildly ill': 1,
#  'delightfully tacky': 1,
#  'really actually good': 1,
#  'more uye': 1,
#  'pretty bad': 22,
#  'so familiar': 2,
#  'ever possible': 1,
#  'super convenient': 6,
#  'always hot always hot always hot ': 1,
#  'fairly quiet': 1,
#  'very overall impressed': 2,
#  'super quick': 5,
#  'marginally only better': 1,
#  'very experienced': 1,
#  'also nice also nice ': 2,
#  'never present': 1,
#  'pretty hesitant': 2,
#  'pretty worth': 1,
#  'super large': 1,
#  'so best': 2,
#  'well sauced': 1,
#  'most welcoming': 3,
#  'pretty basic': 7,
#  'so long': 6,
#  'never horrible': 2,
#  'never great': 1,
#  'how hot': 5,
#  'really undercooked': 2,
#  'pretty huge': 3,
#  'that so hot': 1,
#  'quite impressed': 10,
#  'somewhat dissatisfying': 1,
#  'just gross': 3,
#  'again gross': 1,
#  'actually gross actually gross ': 1,
#  'barely warm': 6,
#  'pretty loud': 4,
#  'usually good': 3,
#  'well mixed': 1,
#  'too slimy': 1,
#  'enough hot': 7,
#  'always good always good always good always good always good ': 2,
#  'never consistent': 1,
#  'definitely great': 3,
#  'pretty slow': 6,
#  'just amazing': 14,
#  'as hot': 3,
#  'somewhat slow': 1,
#  'definitely fresh definitely fresh definitely fresh definitely fresh ': 1,
#  'pretty rammed': 1,
#  'as strong': 1,
#  'just electric': 1,
#  'as far': 1,
#  'so ugly': 2,
#  'very disgusting': 1,
#  'always friendly always friendly always friendly ': 7,
#  'super weird': 1,
#  'under sauced': 1,
#  'completely unimpressed': 1,
#  'super hungry': 8,
#  'too good': 17,
#  'pretty enjoyable': 2,
#  'horribly sick': 2,
#  'otherwise horrible': 1,
#  'probably close': 1,
#  'already full already full already full ': 1,
#  'almost inedible': 3,
#  'completely worth': 2,
#  'very next': 7,
#  'super sweet': 21,
#  'so elegant': 1,
#  'constantly great': 1,
#  'only fair': 1,
#  'here facial': 1,
#  'atmosphere- relaxing': 1,
#  'super personable': 3,
#  'super gentle': 4,
#  'absolutely incredible': 5,
#  'very first': 12,
#  'absolutely wonderful': 9,
#  'very courteous': 14,
#  'very tight': 4,
#  'real happy': 1,
#  'very shady': 1,
#  'as just pricey': 1,
#  'quite pricey': 2,
#  'so easy': 10,
#  'notch!!!,absolutely lovely': 1,
#  'so worried': 5,
#  'well organized': 6,
#  'of uncomfortable': 1,
#  'too way pricey': 1,
#  'incredibly rude': 5,
#  'super disappointing': 3,
#  'ridiculously expensive': 2,
#  'yet so gentle': 1,
#  'by close': 6,
#  'as twice much': 3,
#  'always happy always happy always happy always happy ': 2,
#  'plain mean': 1,
#  'very unkind': 1,
#  'very unpleasant': 6,
#  'totally beautiful': 2,
#  'more pampering': 1,
#  'completely processional': 1,
#  'completely comfortable': 2,
#  'so gentle': 4,
#  'so pleased': 10,
#  'extremely knowledgeable': 8,
#  'whatsoever pushy': 1,
#  'genuinely interested': 3,
#  'so refreshed': 1,
#  'quite serene': 1,
#  'extremely polite': 2,
#  'so clean': 14,
#  'more magical': 1,
#  'absolutely awesome': 3,
#  'reallllly hard': 1,
#  'super smooth': 3,
#  'super interested': 1,
#  'very cranky': 1,
#  'most memorable': 2,
#  'how tight': 2,
#  'just fantastic': 5,
#  'so professional': 5,
#  'as attentive': 3,
#  'incredibly relaxing': 1,
#  'as young': 1,
#  'objectively better objectively better ': 1,
#  'mildly solicitous': 1,
#  'too hot': 13,
#  'deeply disappointed': 1,
#  'extraordinarily better': 1,
#  'extremely gifted': 1,
#  'so creative': 1,
#  'always bad always bad always bad ': 1,
#  'pretty shitty': 1,
#  'too far much': 5,
#  'very appropriate': 1,
#  'surprisingly very busy': 1,
#  'really comfy': 2,
#  'somewhat worried': 1,
#  'so needless': 3,
#  'very special': 6,
#  'equally great': 4,
#  'absolutely disappointed': 1,
#  'absolutely ridiculous': 5,
#  'incredibly attentive': 2,
#  'very beautiful': 8,
#  'so friendly': 55,
#  'super fresh': 14,
#  'super juicy': 6,
#  'slightly gritty': 2,
#  'very bland': 17,
#  'too lackluster': 1,
#  'most successful': 2,
#  'so cheap': 11,
#  'apparently amazing': 1,
#  'as big': 12,
#  'fairly clean': 6,
#  'more definitely genuine': 1,
#  'just delicious': 5,
#  'damn delicious': 1,
#  'all excellent all excellent all excellent all excellent ': 1,
#  'really cool': 27,
#  'perfectly pink': 1,
#  'very juicy': 8,
#  'perfectly prepared': 3,
#  ...}

# %%
total_vocab = [x for x in DF]
print(total_vocab)
# Out:
# ['very good', 'pretty good', 'really good', 'very friendly', 'very busy', 'very pleased', 'at least', 'too much', 'much better', 'too busy', 'very spacious', 'very large', 'very attentive', 'super friendly', 'so good', 'always good always good always good ', 'just typical', 'just average', 'also fantastic also fantastic also fantastic also fantastic ', 'how good', 'how delicious', 'very prompt', 'even fewer', 'real good', 'pretty decent', 'no better', 'most recent', 'pretty average', 'way friendlier', 'exceptionally good', 'extremely greasy', 'very empty', 'enough large', 'barely hot', 'extremely attentive', 'too many', 'super busy', 'really nice', 'so excited', 'too low', 'more interested', 'very nice', 'how busy', 'just wonderful', 'pretty awesome', 'ridiculously good', 'pretty surprisingly darn', 'just sad', 'all exceptional all exceptional ', 'very reasonable', 'very marginal', 'pretty empty', 'always friendly always friendly ', 'decent(not worth decent(not worth decent(not worth decent(not worth ', 'very disappointing', 'all lumpy', 'very perticular', 'so bizarre', 'very expensive', 'very loud', 'just ok', 'definitely worth definitely worth ', 'really small', 'very least', 'less complacent', 'pleasantly surprised', 'just ok just ok just ok ', 'very overpriced', 'very average', 'mostly attentive mostly attentive mostly attentive mostly attentive ', 'really sure', 'so great', 'on great', 'very comfortable', 'at best', 'really plentiful', 'very disappointing!,this', 'that good', 'how wonderful', 'pretty hard', 'little odd', 'maybe few', 'very crunchy', 'often good', 'very rushed', 'super loud', 'so loud', 'fairly quick', 'quite good', 'very saturated', 'all worth', 'very picky', 'how accurate', 'very oily', 'fairly speedy', 'very happy', 'very tasty', 'very kid', 'fairly poor', 'really busy', 'only friendly', 'always huge always huge ', 'so big', 'so many', 'most specific', 'certainly healthy', 'great dry', 'more concerned', 'as many', 'more accurate', 'always prompt always prompt ', 'very dark', 'how dark', 'consistently delicious', 'better good', 'so addictive', 'very fresh', 'so fresh', 'extremely fresh', 'very small', 'pretty busy', 'quite nice', 'quite small', 'that big', 'that great', 'quite busy', 'definitely worth', 'how small', 'too loud', 'well prepared', 'sometimes cold sometimes cold sometimes cold sometimes cold sometimes cold ', 'sometimes hot', 'very again inconsistent', 'generally sub generally sub generally sub generally sub ', 'enough lucky', 'quite full', 'too bit much', 'quite fast', 'slightly cheaper', 'really fresh', 'everywhere albeit same', 'that bad', 'really bad', 'really friendly', 'very enjoyable', 'extremely disappointed', 'very bad', 'always quick always quick ', 'really impressed', 'just regular', 'quite modern', 'always courteous always courteous ', 'loosely packed', 'too chewy', 'still slow', 'more skilled', 'more additional', 'as just satisfying', 'always busy', 'how hungry', 'most shameful', 'strictly japanese', 'somewhat modern', 'really tough', 'how much', 'how many', 'partly due', 'just shocked', 'more expensive', 'very big', 'very limited', 'very convenient', 'pretty small', 'pretty common', 'pretty thin', 'very appealing', 'even busy', 'quite empty', 'quite large', 'neatly furnished', 'slightly upscale', 'much thinner', 'only available', 'too all bad', 'quite impressive', 'so worth', 'most consistent', 'pretty extensive', 'definitely different definitely different ', 'pretty still good', 'also delicious also delicious ', 'really loud', 'very little', 'also full also full ', 'really mushy', 'quite reasonable', 'actually good actually good ', 'more personal', 'usually ready usually ready ', 'very different', 'all fresh all fresh ', 'as extensive', 'really grouchy', 'just great', 'too salty', 'so moist', 'very irritating', 'too small', 'very high', 'quite economical', 'very sullen', 'too late', 'enough big', 'slightly uncomfortable', 'how insulting', 'very uncomfortable', 'probably better ...

# %%
DocumentTF = []
for i, sublist in enumerate(common_phrases_list):
    TF = defaultdict(int)
    adj_phrase_count: int = 0
    for tuples in sublist:
        adj_phrase_count += tuples[1]
    
    for tuples in sublist:
        TF[tuples[0]] = tuples[1]/adj_phrase_count
    DocumentTF.append(TF)

# %%
def computeIDF(word: str) -> float:
    N = len(common_phrases_list)
    num_review = 0
    for reviews in common_phrases_list:
        for review_tuples in reviews:
            if word == review_tuples[0]:
                num_review += 1
    return math.log(N / float(num_review))

# %%
temp_idf_dict = defaultdict(int)
for word in total_vocab:
    temp_idf_dict[word] = computeIDF(word)
# idf_list = [{word: computeIDF(word)} for word in total_vocab]

# %%
DocumentTF[0].keys()
# Out:
# dict_keys(['very good', 'pretty good', 'really good', 'very friendly', 'very busy', 'very pleased', 'at least', 'too much', 'much better', 'too busy', 'very spacious', 'very large', 'very attentive', 'super friendly', 'so good', 'always good always good always good ', 'just typical', 'just average', 'also fantastic also fantastic also fantastic also fantastic ', 'how good', 'how delicious', 'very prompt', 'even fewer', 'real good', 'pretty decent', 'no better', 'most recent', 'pretty average', 'way friendlier', 'exceptionally good', 'extremely greasy', 'very empty', 'enough large', 'barely hot', 'extremely attentive', 'too many', 'super busy', 'really nice', 'so excited', 'too low', 'more interested', 'very nice', 'how busy', 'just wonderful', 'pretty awesome', 'ridiculously good', 'pretty surprisingly darn', 'just sad', 'all exceptional all exceptional ', 'very reasonable', 'very marginal', 'pretty empty', 'always friendly always friendly ', 'decent(not worth decent(not worth decent(not worth decent(not worth ', 'very disappointing', 'all lumpy', 'very perticular', 'so bizarre', 'very expensive', 'very loud', 'just ok', 'definitely worth definitely worth ', 'really small', 'very least', 'less complacent', 'pleasantly surprised', 'just ok just ok just ok ', 'very overpriced', 'very average', 'mostly attentive mostly attentive mostly attentive mostly attentive ', 'really sure', 'so great', 'on great', 'very comfortable', 'at best', 'really plentiful', 'very disappointing!,this', 'that good', 'how wonderful', 'pretty hard', 'little odd', 'maybe few', 'very crunchy', 'often good', 'very rushed', 'super loud', 'so loud', 'fairly quick', 'quite good', 'very saturated', 'all worth', 'very picky', 'how accurate', 'very oily', 'fairly speedy', 'very happy', 'very tasty', 'very kid', 'fairly poor', 'really busy', 'only friendly', 'always huge always huge ', 'so big', 'so many', 'most specific', 'certainly healthy', 'great dry', 'more concerned', 'as many', 'more accurate', 'always prompt always prompt ', 'very dark', 'how dark', 'consistently delicious', 'better good', 'so addictive'])

# %%
DocumentTF[0]['very good']
# Out:
# 0.05806451612903226

# %%
temp_idf_dict['very good']
# Out:
# 0.125163142954006

# %%
def computeTFIDF(TF, idf_list):
    TFIDF = defaultdict(float)
    for phrase in TF.keys():
        phrase_tf_idf = TF[phrase] * idf_list[phrase]
        TFIDF[phrase] = phrase_tf_idf
    return TFIDF

# %%
TFIDFList = [computeTFIDF(TF, temp_idf_dict) for TF in DocumentTF]

# %%
TFIDFList[0]
# Out:
# defaultdict(float,
#             {'very good': 0.007267537332813251,
#              'pretty good': 0.013624686336524191,
#              'really good': 0.007705668511066736,
#              'very friendly': 0.005423389826771577,
#              'very busy': 0.028351284868854448,
#              'very pleased': 0.026455669843795916,
#              'at least': 0.013679303326971788,
#              'too much': 0.005358934252273239,
#              'much better': 0.005617007371068974,
#              'too busy': 0.014175642434427224,
#              'very spacious': 0.0308565237648668,
#              'very large': 0.019407450280984184,
#              'very attentive': 0.012968854589126276,
#              'super friendly': 0.008206306667354796,
#              'so good': 0.004140744775227113,
#              'always good always good always good ': 0.014983146582517582,
#              'just typical': 0.03245443820253184,
#              'just average': 0.016422782397447967,
#              'also fantastic also fantastic also fantastic also fantastic ': 0.03245443820253184,
#              'how good': 0.009703725140492092,
#              'how delicious': 0.017599050505796063,
#              'very prompt': 0.022070967799731195,
#              'even fewer': 0.03245443820253184,
#              'real good': 0.0208946996913831,
#              'pretty decent': 0.008188631004508859,
#              'no better': 0.019038686320726448,
#              'most recent': 0.010956344588498267,
#              'pretty average': 0.01990017917636853,
#              'way friendlier': 0.03245443820253184,
#              'exceptionally good': 0.02351060361466158,
#              'extremely greasy': 0.02536661698531823,
#              'very empty': 0.02798252090859671,
#              'enough large': 0.018278795768104622,
#              'barely hot': 0.02798252090859671,
#              'extremely attentive': 0.019038686320726448,
#              'too many': 0.006839651663485894,
#              'super busy': 0.012225443261053457,
#              'really nice': 0.003945789119973146,
#              'so excited': 0.010299682044563156,
#              'too low': 0.02798252090859671,
#              'more interested': 0.018278795768104622,
#              'very nice': 0.001100809787295248,
#              'how busy': 0.01119097455089101,
#              'just wonderful': 0.022070967799731195,
#              'pretty awesome': 0.014566769026791318,
#              'ridiculously good': 0.02351060361466158,
#              'pretty surprisingly darn': 0.03245443820253184,
#              'just sad': 0.022070967799731195,
#              'all exceptional all exceptional ': 0.03245443820253184,
#              'very reasonable': 0.0060393119946473214,
#              'very marginal': 0.03245443820253184,
#              'pretty empty': 0.018278795768104622,
#              'always friendly always friendly ': 0.014566769026791318,
#              'decent(not worth decent(not worth decent(not worth decent(not worth ': 0.03245443820253184,
#              'very disappointing': 0.010956344588498267,
#              'all lumpy': 0.03245443820253184,
#              'very perticular': 0.03245443820253184,
#              'so bizarre': 0.03245443820253184,
#              'very expensive': 0.014566769026791318,
#              'very loud': 0.0154282618824334,
#              'just ok': 0.00898614039784548,
#              'definitely worth definitely worth ': 0.018278795768104622,
#              'really small': 0.0208946996913831,
#              'very least': 0.01698414611996171,
#              'less complacent': 0.03245443820253184,
#              'pleasantly surprised': 0.005827764750628025,
#              'just ok just ok just ok ': 0.02536661698531823,
#              'very overpriced': 0.02351060361466158,
#              'very average': 0.014983146582517582,
#              'mostly attentive mostly attentive mostly attentive mostly attentive ': 0.03245443820253184,
#              'really sure': 0.019038686320726448,
#              'so great': 0.008340440665219788,
#              'on great': 0.03245443820253184,
#              'very comfortable': 0.012225443261053457,
#              'at best': 0.01119097455089101,
#              'really plentiful': 0.03245443820253184,
#              'very disappointing!,this': 0.03245443820253184,
#              'that good': 0.009516708773567882,
#              'how wonderful': 0.019038686320726448,
#              'pretty hard': 0.0208946996913831,
#              'little odd': 0.02351060361466158,
#              'maybe few': 0.03245443820253184,
#              'very crunchy': 0.02351060361466158,
#              'often good': 0.03245443820253184,
#              'very rushed': 0.0208946996913831,
#              'super loud': 0.02536661698531823,
#              'so loud': 0.018278795768104622,
#              'fairly quick': 0.018278795768104622,
#              'quite good': 0.008340440665219788,
#              'very saturated': 0.03245443820253184,
#              'all worth': 0.018278795768104622,
#              'very picky': 0.01698414611996171,
#              'how accurate': 0.03245443820253184,
#              'very oily': 0.02536661698531823,
#              'fairly speedy': 0.02798252090859671,
#              'very happy': 0.007215580102995415,
#              'very tasty': 0.004953277705491096,
#              'very kid': 0.03245443820253184,
#              'fairly poor': 0.03245443820253184,
#              'really busy': 0.011687497396930547,
#              'only friendly': 0.03245443820253184,
#              'always huge always huge ': 0.03245443820253184,
#              'so big': 0.01590637783181225,
#              'so many': 0.002307155399551802,
#              'most specific': 0.03245443820253184,
#              'certainly healthy': 0.03245443820253184,
#              'great dry': 0.03245443820253184,
#              'more concerned': 0.019038686320726448,
#              'as many': 0.013458057691780613,
#              'more accurate': 0.02798252090859671,
#              'always prompt always prompt ': 0.02536661698531823,
#              'very dark': 0.019038686320726448,
#              'how dark': 0.03245443820253184,
#              'consistently delicious': 0.01990017917636853,
#              'better good': 0.03245443820253184,
#              'so addictive': 0.02536661698531823})

# %%
max_0 = max(TFIDFList[0], key=TFIDFList[0].get)

# %%
max_0
# Out:
# 'just typical'

# %% [markdown]
# ### Cloud tries in jeth.ipynb

# %%
import gensim
from gensim import models
from gensim.models import Word2Vec, KeyedVectors

from gensim.models import Phrases
# Train a bigram detector.
bigram_transformer = Phrases(small_business_phrases)
# remove duplicates
common_phrases_list1 = []
for i in common_phrases_list:
    for j in i:
        common_phrases_list1.append(j[0])
common_phrases_list1 = set(common_phrases_list1)
common_phrases_list1 = list(common_phrases_list1)
# Apply the trained MWE detector to a corpus, using the result to train a Word2vec model.
model = Word2Vec([common_phrases_list1], min_count=1)

# %%
import random
random_word = random.choice(model.wv.index_to_key)

# %%
random_word
# Out:
# 'especially impressed'

# %%
model.wv.most_similar('more creamy')[:5]
# Out:
# [('very cute', 0.3349790871143341),
#  ('really hilarious', 0.3323480486869812),
#  ('really close', 0.32198747992515564),
#  ('quite experienced', 0.3188299834728241),
#  ('extra loud', 0.3151163160800934)]

# %%
rare_phrase = []
for i in common_phrases_list1:
    j = model.wv.most_similar(i)[0][1]
    if j < 0.30:
        rare_phrase.append(i)
rare_phrase
# Out:
# ['overall better']

# %% [markdown]
# ### claudia_tried, claudia_gave_up
# ### jeth_continues

# %%
X = model[model.vocab]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/cr/t5frx0313c365t1gjc3269bnl38nv3/T/ipykernel_57271/1225848386.py in <module>
# ----> 1 X = model[model.vocab]
#
# NameError: name 'model' is not defined

# %%
from nltk.cluster import KMeansClusterer
import nltk
NUM_CLUSTERS=3
kclusterer = KMeansClusterer(NUM_CLUSTERS, distance=nltk.cluster.util.cosine_distance, repeats=25)
assigned_clusters = kclusterer.cluster(X, assign_clusters=True)
print (assigned_clusters)
